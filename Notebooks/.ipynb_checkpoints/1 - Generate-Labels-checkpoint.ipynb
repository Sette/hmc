# %% [markdown]
# ## Análise do genres.csv

# %%
import pandas as pd
import os
import json

# %%
base_path = "/mnt/disks/data/fma"

# %%
metadata_path = os.path.join(base_path,"fma_metadata")

# %% [markdown]
# ## Análise do raw_genres.csv

# %%
raw_genres = os.path.join(metadata_path,"raw_genres.csv")

# %%
df_raw_genres = pd.read_csv(raw_genres)

# %%
df_raw_genres
# Out:
#      genre_id genre_color   genre_handle  genre_parent_id    genre_title
# 0           1     #006666    Avant-Garde             38.0    Avant-Garde
# 1           2     #CC3300  International              NaN  International
# 2           3     #000099          Blues              NaN          Blues
# 3           4     #990099           Jazz              NaN           Jazz
# 4           5     #8A8A65      Classical              NaN      Classical
# ..        ...         ...            ...              ...            ...
# 159      1032     #CC3300        Turkish            102.0        Turkish
# 160      1060     #CC3300          tango             46.0          Tango
# 161      1156     #CC3300           Fado            130.0           Fado
# 162      1193     #D4A017      Christmas            763.0      Christmas
# 163      1235     #000000   Instrumental              NaN   Instrumental
#
# [164 rows x 5 columns]

# %%
df_raw_genres.genre_id
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 159    1032
# 160    1060
# 161    1156
# 162    1193
# 163    1235
# Name: genre_id, Length: 164, dtype: int64

# %%
df_pais =[df_raw_genres[df_raw_genres["genre_id"] == item].values for item in df_raw_genres.genre_id.dropna().values]

# %%
df_pais
# Out:
# [array([[1, '#006666', 'Avant-Garde', 38.0, 'Avant-Garde']], dtype=object),
#  array([[2, '#CC3300', 'International', nan, 'International']],
#        dtype=object),
#  array([[3, '#000099', 'Blues', nan, 'Blues']], dtype=object),
#  array([[4, '#990099', 'Jazz', nan, 'Jazz']], dtype=object),
#  array([[5, '#8A8A65', 'Classical', nan, 'Classical']], dtype=object),
#  array([[6, '#4D0000', 'Novelty', 38.0, 'Novelty']], dtype=object),
#  array([[7, '#009999', 'Comedy', 20.0, 'Comedy']], dtype=object),
#  array([[8, '#665666', 'Old-Time__Historic', nan, 'Old-Time / Historic']],
#        dtype=object),
#  array([[9, '#663366', 'Country', nan, 'Country']], dtype=object),
#  array([[10, '#009900', 'Pop', nan, 'Pop']], dtype=object),
#  array([[11, '#E40089', 'Disco', 14.0, 'Disco']], dtype=object),
#  array([[12, '#840000', 'Rock', nan, 'Rock']], dtype=object),
#  array([[13, '#5B747C', 'Easy_Listening', 126.0, 'Easy Listening']],
#        dtype=object),
# ...

# %% [markdown]
# ## Análise do genres.csv

# %%
genres = os.path.join(metadata_path,"genres.csv")

# %%
df_genres = pd.read_csv(genres)

# %%
df_genres
# Out:
#      genre_id  #tracks  parent          title  top_level
# 0           1     8693      38    Avant-Garde         38
# 1           2     5271       0  International          2
# 2           3     1752       0          Blues          3
# 3           4     4126       0           Jazz          4
# 4           5     4106       0      Classical          5
# ..        ...      ...     ...            ...        ...
# 158      1032       60     102        Turkish          2
# 159      1060       30      46          Tango          2
# 160      1156       26     130           Fado          2
# 161      1193       72     763      Christmas         38
# 162      1235    14938       0   Instrumental       1235
#
# [163 rows x 5 columns]

# %% [markdown]
# ### Geração da hierarquia

# %%
def retorna_estrutura(df,values):
    print(values)
    if values[2] == 0:
        return f'{values[0]}'
    else:
        return f'{values[0]}-{retorna_estrutura(df,df[df["genre_id"]==values[2]].values[0])}'

# %%
def retorna_estrutura(df,values):
    print(values)
    if values[2] == 0:
        return f'{values[0]}'
    else:
        return f'{values[0]}-{retorna_estrutura(df,df[df["genre_id"]==values[2]].values[0])}'

# %%
df_genres.iloc[1].parent
# Out:
# 0

# %%
df_genres.iloc[158].values
# Out:
# array([1032, 60, 102, 'Turkish', 2], dtype=object)

# %%
retorna_estrutura(df_genres,df_genres.iloc[158].values)
# Out:
# [1032 60 102 'Turkish' 2]
# [102 176 2 'Middle East' 2]
# [2 5271 0 'International' 2]
# '1032-102-2'

# %%
[retorna_estrutura(df_genres,item) for item in df_genres.values]
# Out:
# [1 8693 38 'Avant-Garde' 38]
# [38 38154 0 'Experimental' 38]
# [2 5271 0 'International' 2]
# [3 1752 0 'Blues' 3]
# [4 4126 0 'Jazz' 4]
# [5 4106 0 'Classical' 5]
# [6 914 38 'Novelty' 38]
# [38 38154 0 'Experimental' 38]
# [7 217 20 'Comedy' 20]
# [20 1876 0 'Spoken' 20]
# [8 868 0 'Old-Time / Historic' 8]
# [9 1987 0 'Country' 9]
# [10 13845 0 'Pop' 10]
# [11 367 14 'Disco' 14]
# [14 1499 0 'Soul-RnB' 14]
# [12 32923 0 'Rock' 12]
# [13 730 0 'Easy Listening' 13]
# [14 1499 0 'Soul-RnB' 14]
# [15 34413 0 'Electronic' 15]
# [16 304 6 'Sound Effects' 38]
# [6 914 38 'Novelty' 38]
# [38 38154 0 'Experimental' 38]
# [17 12706 0 'Folk' 17]
# [18 5913 1235 'Soundtrack' 1235]
# [1235 14938 0 'Instrumental' 1235]
# [19 773 14 'Funk' 14]
# [14 1499 0 'Soul-RnB' 14]
# [20 1876 0 'Spoken' 20]
# [21 8389 0 'Hip-Hop' 21]
# [22 774 38 'Audio Collage' 38]
# [38 38154 0 'Experimental' 38]
# [25 9261 12 'Punk' 12]
# [12 32923 0 'Rock' 12]
# [26 1952 12 'Post-Rock' 12]
# [12 32923 0 'Rock' 12]
# ...

# %%
def create_labels(arr):
    labels = sorted(list(set(arr)))
    return dict([(label, i) for i, label in enumerate(labels)])

# %%
labels = {
        'global': create_labels(df_tracks_genres.genre_id)
}

# %% [markdown]
# ## Análise do raw_tracks.csv

# %%
raw_tracks = os.path.join(metadata_path,"raw_tracks.csv")

# %%
df_raw_tracks = pd.read_csv(raw_tracks)

# %%
df_raw_tracks
# Out:
#         track_id  album_id                    album_title  \
# 0              2       1.0           AWOL - A Way Of Life
# 1              3       1.0           AWOL - A Way Of Life
# 2              5       1.0           AWOL - A Way Of Life
# 3             10       6.0              Constant Hitmaker
# 4             20       4.0                          Niris
# ...          ...       ...                            ...
# 109722    155316   22940.0  Live at Monty Hall, 2/17/2017
# 109723    155317   22940.0  Live at Monty Hall, 2/17/2017
# 109724    155318   22940.0  Live at Monty Hall, 2/17/2017
# 109725    155319   22940.0  Live at Monty Hall, 2/17/2017
# 109726    155320   22906.0      What I Tell Myself Vol. 2
#
#                                                 album_url  artist_id  \
# 0       http://freemusicarchive.org/music/AWOL/AWOL_-_...          1
# 1       http://freemusicarchive.org/music/AWOL/AWOL_-_...          1
# ...

# %% [markdown]
# ## Generate labels

# %%
df_genres.rename(columns={"#tracks":"track_id"},inplace=True)

# %%
df_tracks_genres = pd.concat([df_raw_tracks, df_genres], axis=1, join="inner")

# %%
df_tracks_genres.genre_id.value_counts()
# Out:
# 1       1
# 401     1
# 247     1
# 250     1
# 267     1
#        ..
# 88      1
# 89      1
# 90      1
# 92      1
# 1235    1
# Name: genre_id, Length: 163, dtype: int64

# %%
def create_labels(arr):
    labels = sorted(list(set(arr)))
    return dict([(label, i) for i, label in enumerate(labels)])

# %%
labels = {
        'global': create_labels(df_tracks_genres.genre_id)
}

# %%
labels
# Out:
# {'global': {1: 0,
#   2: 1,
#   3: 2,
#   4: 3,
#   5: 4,
#   6: 5,
#   7: 6,
#   8: 7,
#   9: 8,
#   10: 9,
#   11: 10,
#   12: 11,
#   13: 12,
#   14: 13,
#   15: 14,
#   16: 15,
#   17: 16,
#   18: 17,
#   19: 18,
#   20: 19,
#   21: 20,
#   22: 21,
#   25: 22,
#   26: 23,
#   27: 24,
#   30: 25,
#   31: 26,
#   32: 27,
#   33: 28,
#   36: 29,
#   37: 30,
#   38: 31,
#   41: 32,
#   42: 33,
#   43: 34,
#   45: 35,
#   46: 36,
#   47: 37,
#   49: 38,
#   53: 39,
#   58: 40,
#   63: 41,
#   64: 42,
#   65: 43,
#   66: 44,
#   70: 45,
#   71: 46,
#   74: 47,
#   76: 48,
#   77: 49,
#   79: 50,
#   81: 51,
#   83: 52,
#   85: 53,
#   86: 54,
#   88: 55,
#   89: 56,
#   90: 57,
#   92: 58,
#   94: 59,
#   97: 60,
#   98: 61,
#   100: 62,
#   101: 63,
#   102: 64,
#   103: 65,
#   107: 66,
#   109: 67,
#   111: 68,
#   113: 69,
#   117: 70,
#   118: 71,
#   125: 72,
#   130: 73,
#   137: 74,
#   138: 75,
#   166: 76,
#   167: 77,
#   169: 78,
#   170: 79,
#   171: 80,
#   172: 81,
# ...

# %%
labels_path = os.path.join(metadata_path,"labels.json")

# %%
with open(labels_path, "w+") as f:
    f.write(json.dumps(labels))
