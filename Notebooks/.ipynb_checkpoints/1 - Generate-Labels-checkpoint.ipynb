# %%
import pandas as pd
import numpy as np
import json
import os
from essentia.standard import MonoLoader
# Out:
# 2023-03-20 18:06:15.857333: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# [   INFO   ] MusicExtractorSVM: no classifier models were configured by default
# 2023-03-20 18:06:16.242685: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-20 18:06:16.244425: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-03-20 18:06:16.287172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:16.287212: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-20 18:06:16.292775: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-03-20 18:06:16.292835: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-03-20 18:06:16.315889: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-03-20 18:06:16.316169: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-03-20 18:06:16.316539: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-03-20 18:06:16.317144: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-03-20 18:06:16.317293: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-03-20 18:06:16.317602: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:16.860847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:16.860869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:16.860873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:16.861344: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:16.866025: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:16.866267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:16.866281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:16.866285: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:16.866289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:16.866535: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:16.870002: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:16.870238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:16.870250: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:16.870254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:16.870258: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:16.870504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.167897: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.168151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.168170: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.168174: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.168177: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.168412: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.175331: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.175557: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.175574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.175578: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.175581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.175812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.178372: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.178612: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.178628: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.178632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.178636: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.178880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.183166: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.183393: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.183410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.183413: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.183417: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.183649: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.183968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.184181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.184191: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.184195: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.184198: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.184421: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.185601: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.185840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.185852: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.185856: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.185859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.186100: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.187475: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.187705: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.187715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.187719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.187722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.187955: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.189029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.189241: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.189250: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.189255: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.189258: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.189479: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.191175: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.191390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.191400: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.191403: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.191406: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.191629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.194232: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.194469: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.194482: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.194486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.194490: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.194733: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.197693: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.197940: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.197956: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.197960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.197964: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.198210: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.200739: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.200986: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.201004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.201008: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.201011: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.201259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.204343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.204586: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.204604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.204608: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.204611: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.204860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.207509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.207770: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.207789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.207793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.207797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.208044: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.211070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.211298: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.211314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.211318: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.211321: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.211551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2023-03-20 18:06:17.214117: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-03-20 18:06:17.214360: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-20 18:06:17.214378: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-20 18:06:17.214382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-20 18:06:17.214386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-20 18:06:17.214632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9669 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)

# %%
from tqdm.notebook import tqdm

# %%
tqdm.pandas()

# %%
args = pd.Series({
    "root_dir":"/mnt/disks/data/",
    "dataset_path":"/mnt/disks/data/fma/fma_large",
    "embeddings":"music_style",
    "train_id": "hierarchical_mini_test",
    'sample_size':0.01
})

# %%
job_path = "/mnt/disks/data/fma/trains"


# In[15]:


train_path = os.path.join(job_path,args.train_id)


# In[16]:


base_path = os.path.join(args.root_dir,"fma")


# In[17]:


models_path = os.path.join(args.root_dir,"models")


metadata_path_fma = os.path.join(base_path,"fma_metadata")


# In[18]:


metadata_file = os.path.join(train_path,"metadata.json")


categories_labels_path = os.path.join(train_path,"labels.json")

# %%
def __load_json__(path):
    with open(path, 'r') as f:
        tmp = json.loads(f.read())

    return tmp

# %%
def create_dir(path):
    # checking if the directory demo_folder2 
    # exist or not.
    if not os.path.isdir(path):

        # if the demo_folder2 directory is 
        # not present then create it.
        os.makedirs(path)
    return True

# %%
create_dir(train_path)
# Out:
# True

# %% [markdown]
# ## Load genres file. Contains relationships beetwen genres

# %%
genres_df = pd.read_csv(os.path.join(metadata_path_fma,'genres.csv'))

# %%
genres_df
# Out:
#      genre_id  #tracks  parent          title  top_level
# 0           1     8693      38    Avant-Garde         38
# 1           2     5271       0  International          2
# 2           3     1752       0          Blues          3
# 3           4     4126       0           Jazz          4
# 4           5     4106       0      Classical          5
# ..        ...      ...     ...            ...        ...
# 158      1032       60     102        Turkish          2
# 159      1060       30      46          Tango          2
# 160      1156       26     130           Fado          2
# 161      1193       72     763      Christmas         38
# 162      1235    14938       0   Instrumental       1235
#
# [163 rows x 5 columns]

# %%
genres_df[genres_df['genre_id'] == 76]
# Out:
#     genre_id  #tracks  parent             title  top_level
# 48        76     7144      10  Experimental Pop         10

# %%
# Filtra as colunas relevantes
genres = genres_df[['genre_id', 'parent']]

# Cria um dicionário que mapeia o ID de cada gênero musical aos IDs de seus subgêneros
genre_dict = {}
for i, row in genres.iterrows():
    genre_id = row['genre_id']
    parent_id = row['parent']
    if pd.notna(parent_id):
        if parent_id not in genre_dict:
            genre_dict[parent_id] = []
        genre_dict[parent_id].append(genre_id)

# %%
genre_dict
# Out:
# {38: [1, 6, 22, 30, 32, 41, 47, 125, 186, 224, 247, 250, 456, 514],
#  0: [2, 3, 4, 5, 8, 9, 10, 12, 13, 14, 15, 17, 20, 21, 38, 1235],
#  20: [7, 65, 138, 188, 374, 378, 428, 465],
#  14: [11, 19],
#  6: [16, 360],
#  1235: [18, 107, 267],
#  12: [25, 26, 27, 31, 36, 45, 58, 66, 70, 85, 88, 98, 314, 359, 440],
#  17: [33, 49, 94, 103, 180],
#  4: [37, 74, 97, 178, 179, 906],
#  15: [42, 181, 182, 183, 184, 185, 236, 286, 296, 297, 337, 468, 495, 695],
#  65: [43, 166, 189],
#  2: [46, 77, 79, 86, 92, 102, 117, 118, 130, 171, 172, 176, 177, 232, 504],
#  45: [53],
#  9: [63, 137, 169, 651],
#  25: [64, 71, 89, 109, 111],
#  10: [76, 362],
#  92: [81, 214],
#  21: [83, 100, 539, 542, 580, 693, 811],
#  53: [90],
#  31: [101, 167, 439],
#  26: [113],
#  13: [170, 311, 810],
#  86: [173, 174, 175],
#  5: [187, 322, 441, 442, 443, 444, 659],
#  297: [240],
#  109: [361],
#  19: [377],
#  182: [400],
#  181: [401],
#  85: [404],
#  468: [491],
#  651: [493],
#  46: [502, 808, 1060],
#  130: [524, 619, 741, 1156],
#  18: [538],
#  3: [567],
#  79: [602],
#  16: [763],
#  102: [1032],
#  763: [1193]}

# %%
# Cria um dicionário que associa o ID de cada música aos IDs de seus gêneros musicais
tracks_df = pd.read_csv(os.path.join(metadata_path_fma,'tracks.csv'), header=[0,1], index_col=0)

# %%
tracks_df
# Out:
#             album                                                     \
#          comments         date_created        date_released engineer
# track_id
# 2               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10              0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 20              0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
# ...           ...                  ...                  ...      ...
# 155316          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155317          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155318          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155319          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155320          0  2017-03-26 16:22:18  2017-03-26 00:00:00      NaN
#
#                                                                               \
#          favorites     id                                        information
# track_id
# 2                4      1                                            <p></p>
# 3                4      1                                            <p></p>
# 5                4      1                                            <p></p>
# 10               4      6                                                NaN
# 20               2      4          <p> "spiritual songs" from Nicky Cook</p>
# ...            ...    ...                                                ...
# 155316           0  22940  <p>A live performance at Monty Hall on Feb 17,...
# 155317           0  22940  <p>A live performance at Monty Hall on Feb 17,...
# 155318           0  22940  <p>A live performance at Monty Hall on Feb 17,...
# 155319           0  22940  <p>A live performance at Monty Hall on Feb 17,...
# 155320           1  22906                                                NaN
#
#                                \
#          listens     producer
# track_id
# 2           6073          NaN
# 3           6073          NaN
# 5           6073          NaN
# 10         47632          NaN
# 20          2710          NaN
# ...          ...          ...
# 155316      1506  Monty Hall
# 155317      1506  Monty Hall
# 155318      1506  Monty Hall
# 155319      1506  Monty Hall
# 155320      7481          NaN
#
#                                                              ...       track  \
#                                                        tags  ... information
# track_id                                                     ...
# 2                                                        []  ...         NaN
# 3                                                        []  ...         NaN
# 5                                                        []  ...         NaN
# 10                                                       []  ...         NaN
# 20                                                       []  ...         NaN
# ...                                                     ...  ...         ...
# 155316                                                   []  ...         NaN
# 155317                                                   []  ...         NaN
# 155318                                                   []  ...         NaN
# 155319                                                   []  ...         NaN
# 155320    ['ballad', 'epic', 'rockabilly', 'curse', 'hex...  ...         NaN
#
#                                  \
#          interest language_code
# track_id
# 2            4656            en
# 3            1470            en
# 5            1933            en
# 10          54881            en
# 20            978            en
# ...           ...           ...
# 155316        122           NaN
# 155317        194           NaN
# 155318        214           NaN
# 155319        336           NaN
# 155320        972           NaN
#
#                                                                               \
#                                                     license listens lyricist
# track_id
# 2         Attribution-NonCommercial-ShareAlike 3.0 Inter...    1293      NaN
# 3         Attribution-NonCommercial-ShareAlike 3.0 Inter...     514      NaN
# 5         Attribution-NonCommercial-ShareAlike 3.0 Inter...    1151      NaN
# 10        Attribution-NonCommercial-NoDerivatives (aka M...   50135      NaN
# 20        Attribution-NonCommercial-NoDerivatives (aka M...     361      NaN
# ...                                                     ...     ...      ...
# 155316    Creative Commons Attribution-NonCommercial-NoD...     102      NaN
# 155317    Creative Commons Attribution-NonCommercial-NoD...     165      NaN
# 155318    Creative Commons Attribution-NonCommercial-NoD...     168      NaN
# 155319    Creative Commons Attribution-NonCommercial-NoD...     294      NaN
# 155320                            Attribution-NonCommercial     705      NaN
#
#                                                                               \
#          number publisher                                               tags
# track_id
# 2             3       NaN                                                 []
# 3             4       NaN                                                 []
# 5             6       NaN                                                 []
# 10            1       NaN                                                 []
# 20            3       NaN                                                 []
# ...         ...       ...                                                ...
# 155316        3       NaN                                                 []
# 155317        4       NaN                                                 []
# 155318        6       NaN                                                 []
# 155319        5       NaN                                                 []
# 155320        7       NaN  ['ballad', 'epic', 'rockabilly', 'curse', 'hex...
#
#
#                                               title
# track_id
# 2                                              Food
# 3                                      Electric Ave
# 5                                        This World
# 10                                          Freeway
# 20                                  Spiritual Level
# ...                                             ...
# 155316                                    The Auger
# 155317                              Let's Skin Ruby
# 155318           My House Smells Like Kim Deal/Pulp
# 155319                      The Man With Two Mouths
# 155320    Another Trick Up My Sleeve (Instrumental)
#
# [106574 rows x 52 columns]

# %%
tracks_df.track.genres.value_counts()
# Out:
# [21]                    2735
# [15]                    2689
# []                      2231
# [12]                    1896
# [1, 30, 38, 41, 247]    1633
#                         ...
# [12, 542]                  1
# [92, 602]                  1
# [102, 189]                 1
# [14, 30, 92]               1
# [10, 12, 169]              1
# Name: genres, Length: 4768, dtype: int64

# %%
tracks_df['valid_genre'] = tracks_df.track.genres.apply(lambda x: x.strip('][').split(', ') if x != '[]' else None)

# %%
tracks_df.valid_genre.dropna()
# Out:
# track_id
# 2                  [21]
# 3                  [21]
# 5                  [21]
# 10                 [10]
# 20            [76, 103]
#               ...
# 155316             [25]
# 155317             [25]
# 155318             [25]
# 155319             [25]
# 155320    [10, 12, 169]
# Name: valid_genre, Length: 104343, dtype: object

# %%
tracks_df.track.genre_top
# Out:
# track_id
# 2         Hip-Hop
# 3         Hip-Hop
# 5         Hip-Hop
# 10            Pop
# 20            NaN
#            ...
# 155316       Rock
# 155317       Rock
# 155318       Rock
# 155319       Rock
# 155320        NaN
# Name: genre_top, Length: 106574, dtype: object

# %%
tracks_df.track
# Out:
#           bit_rate  comments   composer         date_created  \
# track_id
# 2           256000         0        NaN  2008-11-26 01:48:12
# 3           256000         0        NaN  2008-11-26 01:48:14
# 5           256000         0        NaN  2008-11-26 01:48:20
# 10          192000         0  Kurt Vile  2008-11-25 17:49:06
# 20          256000         0        NaN  2008-11-26 01:48:56
# ...            ...       ...        ...                  ...
# 155316      320000         0        NaN  2017-03-30 15:23:34
# 155317      320000         0        NaN  2017-03-30 15:23:36
# 155318      320000         0        NaN  2017-03-30 15:23:37
# 155319      320000         0        NaN  2017-03-30 15:23:39
# 155320      320000         0        NaN  2017-03-30 09:15:36
#
#                 date_recorded  duration  favorites genre_top         genres  \
# track_id
# 2         2008-11-26 00:00:00       168          2   Hip-Hop           [21]
# 3         2008-11-26 00:00:00       237          1   Hip-Hop           [21]
# 5         2008-11-26 00:00:00       206          6   Hip-Hop           [21]
# 10        2008-11-26 00:00:00       161        178       Pop           [10]
# 20        2008-01-01 00:00:00       311          0       NaN      [76, 103]
# ...                       ...       ...        ...       ...            ...
# 155316                    NaN       162          1      Rock           [25]
# 155317                    NaN       217          1      Rock           [25]
# 155318                    NaN       404          2      Rock           [25]
# 155319                    NaN       146          0      Rock           [25]
# 155320                    NaN       198          1       NaN  [10, 12, 169]
#
#                  genres_all information  interest language_code  \
# track_id
# 2                      [21]         NaN      4656            en
# 3                      [21]         NaN      1470            en
# 5                      [21]         NaN      1933            en
# 10                     [10]         NaN     54881            en
# 20        [17, 10, 76, 103]         NaN       978            en
# ...                     ...         ...       ...           ...
# 155316             [25, 12]         NaN       122           NaN
# 155317             [25, 12]         NaN       194           NaN
# 155318             [25, 12]         NaN       214           NaN
# 155319             [25, 12]         NaN       336           NaN
# 155320     [169, 10, 12, 9]         NaN       972           NaN
#
#                                                     license  listens lyricist  \
# track_id
# 2         Attribution-NonCommercial-ShareAlike 3.0 Inter...     1293      NaN
# 3         Attribution-NonCommercial-ShareAlike 3.0 Inter...      514      NaN
# 5         Attribution-NonCommercial-ShareAlike 3.0 Inter...     1151      NaN
# 10        Attribution-NonCommercial-NoDerivatives (aka M...    50135      NaN
# 20        Attribution-NonCommercial-NoDerivatives (aka M...      361      NaN
# ...                                                     ...      ...      ...
# 155316    Creative Commons Attribution-NonCommercial-NoD...      102      NaN
# 155317    Creative Commons Attribution-NonCommercial-NoD...      165      NaN
# 155318    Creative Commons Attribution-NonCommercial-NoD...      168      NaN
# 155319    Creative Commons Attribution-NonCommercial-NoD...      294      NaN
# 155320                            Attribution-NonCommercial      705      NaN
#
#           number publisher                                               tags  \
# track_id
# 2              3       NaN                                                 []
# 3              4       NaN                                                 []
# 5              6       NaN                                                 []
# 10             1       NaN                                                 []
# 20             3       NaN                                                 []
# ...          ...       ...                                                ...
# 155316         3       NaN                                                 []
# 155317         4       NaN                                                 []
# 155318         6       NaN                                                 []
# 155319         5       NaN                                                 []
# 155320         7       NaN  ['ballad', 'epic', 'rockabilly', 'curse', 'hex...
#
#                                               title
# track_id
# 2                                              Food
# 3                                      Electric Ave
# 5                                        This World
# 10                                          Freeway
# 20                                  Spiritual Level
# ...                                             ...
# 155316                                    The Auger
# 155317                              Let's Skin Ruby
# 155318           My House Smells Like Kim Deal/Pulp
# 155319                      The Man With Two Mouths
# 155320    Another Trick Up My Sleeve (Instrumental)
#
# [106574 rows x 20 columns]

# %%
genre_tracks_dict = {}
for track_id, track_genres in tracks_df.valid_genre.dropna().items():
    # track_genres = row[('track', 'genres')].split('|')[0]
    # track_genres = track_genres.strip('][').split(', ')
    # print(track_genres)
    track_genre_ids = []
    genre = track_genres[0]
    if int(genre) in genre_dict:
        track_genre_ids.extend(genre_dict[int(genre)])
    track_genre_ids.append(int(genre))
    genre_tracks_dict[track_id] = list(reversed(track_genre_ids))

# %%
genre_tracks_dict
# Out:
# {2: [21, 811, 693, 580, 542, 539, 100, 83],
#  3: [21, 811, 693, 580, 542, 539, 100, 83],
#  5: [21, 811, 693, 580, 542, 539, 100, 83],
#  10: [10, 362, 76],
#  20: [76],
#  26: [76],
#  30: [76],
#  46: [76],
#  48: [76],
#  134: [21, 811, 693, 580, 542, 539, 100, 83],
#  135: [45, 53],
#  136: [45, 53],
#  137: [1],
#  138: [1],
#  139: [17, 180, 103, 94, 49, 33],
#  140: [17, 180, 103, 94, 49, 33],
#  141: [17, 180, 103, 94, 49, 33],
#  142: [17, 180, 103, 94, 49, 33],
#  144: [4, 906, 179, 178, 97, 74, 37],
#  145: [4, 906, 179, 178, 97, 74, 37],
#  146: [4, 906, 179, 178, 97, 74, 37],
#  147: [4, 906, 179, 178, 97, 74, 37],
#  148: [1],
#  149: [1],
#  150: [1],
#  151: [25, 111, 109, 89, 71, 64],
#  152: [25, 111, 109, 89, 71, 64],
#  153: [26, 113],
#  154: [26, 113],
#  155: [26, 113],
#  156: [30],
#  157: [30],
#  158: [30],
#  159: [30],
#  160: [30],
#  161: [30],
#  162: [30],
#  163: [30],
#  164: [30],
#  165: [30],
#  166: [30],
#  167: [30],
#  168: [30],
#  169: [25, 111, 109, 89, 71, 64],
#  170: [25, 111, 109, 89, 71, 64],
#  171: [25, 111, 109, 89, 71, 64],
#  172: [25, 111, 109, 89, 71, 64],
#  173: [25, 111, 109, 89, 71, 64],
#  174: [25, 111, 109, 89, 71, 64],
#  175: [25, 111, 109, 89, 71, 64],
#  176: [25, 111, 109, 89, 71, 64],
#  177: [25, 111, 109, 89, 71, 64],
#  178: [25, 111, 109, 89, 71, 64],
#  179: [25, 111, 109, 89, 71, 64],
#  181: [27],
#  182: [27],
#  183: [27],
#  184: [27],
#  185: [27],
#  188: [17, 180, 103, 94, 49, 33],
#  189: [17, 180, 103, 94, 49, 33],
#  190: [17, 180, 103, 94, 49, 33],
#  191: [17, 180, 103, 94, 49, 33],
#  192: [17, 180, 103, 94, 49, 33],
#  193: [17, 180, 103, 94, 49, 33],
#  194: [17, 180, 103, 94, 49, 33],
#  195: [17, 180, 103, 94, 49, 33],
#  196: [17, 180, 103, 94, 49, 33],
#  197: [17, 180, 103, 94, 49, 33],
#  198: [17, 180, 103, 94, 49, 33],
#  199: [17, 180, 103, 94, 49, 33],
#  200: [17, 180, 103, 94, 49, 33],
#  201: [17, 180, 103, 94, 49, 33],
#  202: [17, 180, 103, 94, 49, 33],
#  203: [17, 180, 103, 94, 49, 33],
#  204: [17, 180, 103, 94, 49, 33],
#  205: [17, 180, 103, 94, 49, 33],
#  206: [17, 180, 103, 94, 49, 33],
#  207: [17, 180, 103, 94, 49, 33],
#  208: [17, 180, 103, 94, 49, 33],
#  209: [17, 180, 103, 94, 49, 33],
#  210: [17, 180, 103, 94, 49, 33],
#  211: [17, 180, 103, 94, 49, 33],
#  212: [17, 180, 103, 94, 49, 33],
#  213: [10, 362, 76],
#  226: [25, 111, 109, 89, 71, 64],
#  228: [25, 111, 109, 89, 71, 64],
#  236: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  237: [4, 906, 179, 178, 97, 74, 37],
#  238: [4, 906, 179, 178, 97, 74, 37],
#  246: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  247: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  248: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  249: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  250: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  251: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  252: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  253: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  254: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  255: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  256: [31, 439, 167, 101],
#  257: [31, 439, 167, 101],
#  258: [31, 439, 167, 101],
#  273: [32],
#  274: [32],
#  275: [32],
#  276: [32],
#  277: [32],
#  281: [32],
#  282: [32],
#  284: [32],
#  285: [32],
#  293: [32],
#  294: [32],
#  297: [32],
#  300: [32],
#  303: [89],
#  304: [89],
#  305: [89],
#  306: [89],
#  307: [89],
#  308: [89],
#  309: [89],
#  310: [89],
#  311: [89],
#  312: [89],
#  313: [89],
#  314: [89],
#  315: [89],
#  316: [89],
#  317: [89],
#  318: [89],
#  319: [89],
#  320: [89],
#  321: [89],
#  322: [89],
#  323: [89],
#  324: [89],
#  325: [89],
#  326: [89],
#  327: [89],
#  328: [89],
#  330: [89],
#  331: [89],
#  332: [89],
#  333: [89],
#  334: [89],
#  335: [89],
#  336: [89],
#  337: [89],
#  338: [89],
#  339: [89],
#  340: [89],
#  341: [89],
#  342: [89],
#  343: [89],
#  344: [89],
#  345: [89],
#  346: [89],
#  347: [89],
#  348: [89],
#  349: [89],
#  350: [89],
#  351: [89],
#  352: [89],
#  353: [89],
#  354: [89],
#  355: [89],
#  356: [89],
#  357: [89],
#  358: [89],
#  359: [89],
#  360: [89],
#  361: [89],
#  362: [89],
#  363: [89],
#  364: [89],
#  365: [89],
#  366: [89],
#  367: [89],
#  368: [89],
#  369: [89],
#  370: [89],
#  371: [89],
#  384: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  385: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  386: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  387: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  393: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  394: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  395: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  396: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  397: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  398: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  399: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  400: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  401: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  402: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  403: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  404: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  405: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  406: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  407: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  408: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  410: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  411: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  412: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  414: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  416: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  417: [1],
#  418: [1],
#  419: [1],
#  420: [1],
#  421: [1],
#  422: [1],
#  423: [1],
#  424: [1],
#  425: [1],
#  426: [1],
#  427: [1],
#  428: [1],
#  429: [1],
#  430: [1],
#  431: [1],
#  432: [1],
#  433: [1],
#  434: [1],
#  435: [1],
#  436: [1],
#  437: [1],
#  438: [1],
#  439: [1],
#  440: [4, 906, 179, 178, 97, 74, 37],
#  441: [4, 906, 179, 178, 97, 74, 37],
#  442: [4, 906, 179, 178, 97, 74, 37],
#  443: [4, 906, 179, 178, 97, 74, 37],
#  444: [4, 906, 179, 178, 97, 74, 37],
#  445: [4, 906, 179, 178, 97, 74, 37],
#  446: [4, 906, 179, 178, 97, 74, 37],
#  447: [4, 906, 179, 178, 97, 74, 37],
#  448: [4, 906, 179, 178, 97, 74, 37],
#  449: [4, 906, 179, 178, 97, 74, 37],
#  450: [4, 906, 179, 178, 97, 74, 37],
#  451: [4, 906, 179, 178, 97, 74, 37],
#  452: [4, 906, 179, 178, 97, 74, 37],
#  458: [36],
#  459: [36],
#  461: [3, 567],
#  462: [3, 567],
#  463: [3, 567],
#  464: [3, 567],
#  465: [3, 567],
#  466: [27],
#  467: [27],
#  468: [25, 111, 109, 89, 71, 64],
#  469: [27],
#  470: [27],
#  471: [27],
#  472: [27],
#  473: [27],
#  474: [25, 111, 109, 89, 71, 64],
#  475: [27],
#  476: [27],
#  477: [25, 111, 109, 89, 71, 64],
#  478: [27],
#  479: [27],
#  480: [25, 111, 109, 89, 71, 64],
#  481: [27],
#  482: [27],
#  483: [27],
#  484: [27],
#  485: [25, 111, 109, 89, 71, 64],
#  486: [27],
#  487: [27],
#  489: [27],
#  490: [27],
#  491: [27],
#  492: [27],
#  493: [27],
#  495: [25, 111, 109, 89, 71, 64],
#  496: [27],
#  497: [27],
#  498: [27],
#  500: [27],
#  501: [27],
#  502: [25, 111, 109, 89, 71, 64],
#  503: [27],
#  504: [27],
#  506: [27],
#  507: [27],
#  508: [27],
#  509: [27],
#  510: [27],
#  511: [27],
#  512: [27],
#  513: [27],
#  514: [27],
#  515: [27],
#  516: [27],
#  517: [27],
#  520: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  521: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  522: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  523: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  524: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  525: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  526: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  527: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  528: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  529: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  530: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  531: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  532: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  533: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  534: [17, 180, 103, 94, 49, 33],
#  535: [17, 180, 103, 94, 49, 33],
#  536: [17, 180, 103, 94, 49, 33],
#  537: [17, 180, 103, 94, 49, 33],
#  538: [17, 180, 103, 94, 49, 33],
#  539: [17, 180, 103, 94, 49, 33],
#  540: [17, 180, 103, 94, 49, 33],
#  541: [17, 180, 103, 94, 49, 33],
#  542: [17, 180, 103, 94, 49, 33],
#  543: [17, 180, 103, 94, 49, 33],
#  544: [17, 180, 103, 94, 49, 33],
#  545: [17, 180, 103, 94, 49, 33],
#  546: [17, 180, 103, 94, 49, 33],
#  547: [17, 180, 103, 94, 49, 33],
#  548: [17, 180, 103, 94, 49, 33],
#  549: [17, 180, 103, 94, 49, 33],
#  550: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  554: [76],
#  555: [76],
#  556: [76],
#  557: [76],
#  558: [76],
#  559: [76],
#  560: [76],
#  561: [76],
#  562: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  563: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  564: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  565: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  566: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  567: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  568: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  569: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  570: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  571: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  572: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  573: [25, 111, 109, 89, 71, 64],
#  574: [25, 111, 109, 89, 71, 64],
#  575: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  576: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  577: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  578: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  579: [25, 111, 109, 89, 71, 64],
#  580: [25, 111, 109, 89, 71, 64],
#  583: [21, 811, 693, 580, 542, 539, 100, 83],
#  584: [21, 811, 693, 580, 542, 539, 100, 83],
#  585: [21, 811, 693, 580, 542, 539, 100, 83],
#  586: [21, 811, 693, 580, 542, 539, 100, 83],
#  587: [1],
#  588: [1],
#  589: [1],
#  590: [37],
#  591: [37],
#  592: [37],
#  593: [37],
#  601: [17, 180, 103, 94, 49, 33],
#  602: [17, 180, 103, 94, 49, 33],
#  603: [17, 180, 103, 94, 49, 33],
#  604: [17, 180, 103, 94, 49, 33],
#  605: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  606: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  607: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  608: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  609: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  610: [17, 180, 103, 94, 49, 33],
#  611: [17, 180, 103, 94, 49, 33],
#  612: [17, 180, 103, 94, 49, 33],
#  614: [17, 180, 103, 94, 49, 33],
#  615: [41],
#  616: [41],
#  617: [17, 180, 103, 94, 49, 33],
#  618: [17, 180, 103, 94, 49, 33],
#  619: [17, 180, 103, 94, 49, 33],
#  620: [17, 180, 103, 94, 49, 33],
#  621: [17, 180, 103, 94, 49, 33],
#  622: [17, 180, 103, 94, 49, 33],
#  623: [17, 180, 103, 94, 49, 33],
#  624: [17, 180, 103, 94, 49, 33],
#  625: [17, 180, 103, 94, 49, 33],
#  626: [17, 180, 103, 94, 49, 33],
#  627: [17, 180, 103, 94, 49, 33],
#  628: [17, 180, 103, 94, 49, 33],
#  629: [17, 180, 103, 94, 49, 33],
#  630: [17, 180, 103, 94, 49, 33],
#  631: [17, 180, 103, 94, 49, 33],
#  633: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  634: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  635: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  637: [1],
#  638: [1],
#  639: [1],
#  640: [43],
#  641: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  642: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  643: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  644: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  645: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  646: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  647: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  648: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  649: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  650: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  651: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  652: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  653: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  654: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  655: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  656: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  657: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  658: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  659: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  660: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  661: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  662: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  663: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  664: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  665: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  666: [79, 602],
#  667: [79, 602],
#  668: [21, 811, 693, 580, 542, 539, 100, 83],
#  669: [21, 811, 693, 580, 542, 539, 100, 83],
#  670: [21, 811, 693, 580, 542, 539, 100, 83],
#  671: [21, 811, 693, 580, 542, 539, 100, 83],
#  672: [21, 811, 693, 580, 542, 539, 100, 83],
#  673: [21, 811, 693, 580, 542, 539, 100, 83],
#  674: [21, 811, 693, 580, 542, 539, 100, 83],
#  675: [21, 811, 693, 580, 542, 539, 100, 83],
#  676: [21, 811, 693, 580, 542, 539, 100, 83],
#  677: [21, 811, 693, 580, 542, 539, 100, 83],
#  678: [21, 811, 693, 580, 542, 539, 100, 83],
#  679: [21, 811, 693, 580, 542, 539, 100, 83],
#  680: [21, 811, 693, 580, 542, 539, 100, 83],
#  681: [21, 811, 693, 580, 542, 539, 100, 83],
#  682: [21, 811, 693, 580, 542, 539, 100, 83],
#  683: [21, 811, 693, 580, 542, 539, 100, 83],
#  684: [21, 811, 693, 580, 542, 539, 100, 83],
#  685: [21, 811, 693, 580, 542, 539, 100, 83],
#  686: [21, 811, 693, 580, 542, 539, 100, 83],
#  687: [21, 811, 693, 580, 542, 539, 100, 83],
#  688: [21, 811, 693, 580, 542, 539, 100, 83],
#  689: [21, 811, 693, 580, 542, 539, 100, 83],
#  690: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  691: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  692: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  693: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  694: [21, 811, 693, 580, 542, 539, 100, 83],
#  695: [21, 811, 693, 580, 542, 539, 100, 83],
#  696: [45, 53],
#  697: [45, 53],
#  698: [45, 53],
#  699: [45, 53],
#  700: [45, 53],
#  701: [45, 53],
#  702: [45, 53],
#  703: [45, 53],
#  704: [46, 1060, 808, 502],
#  705: [46, 1060, 808, 502],
#  706: [46, 1060, 808, 502],
#  707: [46, 1060, 808, 502],
#  708: [46, 1060, 808, 502],
#  709: [46, 1060, 808, 502],
#  711: [25, 111, 109, 89, 71, 64],
#  712: [25, 111, 109, 89, 71, 64],
#  713: [25, 111, 109, 89, 71, 64],
#  714: [17, 180, 103, 94, 49, 33],
#  715: [17, 180, 103, 94, 49, 33],
#  716: [17, 180, 103, 94, 49, 33],
#  717: [17, 180, 103, 94, 49, 33],
#  718: [17, 180, 103, 94, 49, 33],
#  719: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  720: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  721: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  722: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  723: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  725: [32],
#  726: [32],
#  727: [32],
#  728: [32],
#  729: [32],
#  730: [32],
#  731: [32],
#  734: [11],
#  735: [11],
#  736: [11],
#  737: [11],
#  738: [11],
#  739: [11],
#  740: [11],
#  741: [11],
#  742: [11],
#  743: [11],
#  744: [11],
#  745: [11],
#  747: [11],
#  748: [11],
#  749: [11],
#  750: [11],
#  751: [11],
#  752: [11],
#  753: [11],
#  754: [11],
#  755: [11],
#  756: [11],
#  757: [11],
#  758: [11],
#  759: [11],
#  760: [11],
#  761: [11],
#  762: [11],
#  763: [11],
#  764: [11],
#  765: [11],
#  766: [11],
#  767: [11],
#  768: [11],
#  769: [11],
#  770: [11],
#  771: [11],
#  772: [11],
#  773: [11],
#  774: [11],
#  775: [11],
#  776: [11],
#  777: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  778: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  779: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  780: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  781: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  782: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  783: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  784: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  785: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  786: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  787: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  788: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  789: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  790: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  791: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  792: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  793: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  794: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  795: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  796: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  797: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  798: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  799: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  800: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  801: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  803: [25, 111, 109, 89, 71, 64],
#  804: [25, 111, 109, 89, 71, 64],
#  805: [25, 111, 109, 89, 71, 64],
#  806: [25, 111, 109, 89, 71, 64],
#  807: [25, 111, 109, 89, 71, 64],
#  814: [17, 180, 103, 94, 49, 33],
#  815: [1],
#  816: [1],
#  817: [1],
#  818: [1],
#  819: [1],
#  820: [1],
#  821: [10, 362, 76],
#  822: [10, 362, 76],
#  823: [10, 362, 76],
#  824: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  825: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  826: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  827: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  828: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  829: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  830: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  831: [37],
#  832: [37],
#  833: [37],
#  834: [37],
#  835: [37],
#  836: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  837: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  838: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  839: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  840: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  841: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  842: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  843: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  844: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  845: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  846: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  847: [10, 362, 76],
#  850: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  851: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  852: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  853: [2,
#   504,
#   232,
#   177,
#   176,
#   172,
#   171,
#   130,
#   118,
#   117,
#   102,
#   92,
#   86,
#   79,
#   77,
#   46],
#  854: [32],
#  855: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  856: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  857: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  858: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  859: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  860: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  861: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  862: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  863: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  864: [47],
#  866: [47],
#  868: [47],
#  869: [47],
#  870: [47],
#  871: [33],
#  872: [33],
#  873: [33],
#  874: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  875: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  876: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  877: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  878: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  879: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  880: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  881: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  882: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  883: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  885: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  886: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  887: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  888: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  889: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  890: [49],
#  891: [49],
#  892: [49],
#  893: [49],
#  894: [49],
#  895: [49],
#  896: [25, 111, 109, 89, 71, 64],
#  897: [32],
#  898: [32],
#  899: [32],
#  900: [250],
#  901: [250],
#  902: [250],
#  903: [250],
#  904: [138],
#  905: [138],
#  906: [138],
#  907: [138],
#  908: [138],
#  909: [138],
#  910: [138],
#  911: [138],
#  912: [138],
#  913: [138],
#  914: [138],
#  915: [138],
#  916: [138],
#  917: [138],
#  918: [138],
#  919: [138],
#  920: [138],
#  921: [138],
#  922: [138],
#  923: [138],
#  924: [138],
#  925: [138],
#  926: [138],
#  927: [138],
#  928: [138],
#  929: [138],
#  930: [138],
#  931: [138],
#  932: [138],
#  933: [138],
#  934: [138],
#  935: [138],
#  936: [138],
#  937: [138],
#  938: [138],
#  939: [138],
#  940: [138],
#  941: [138],
#  942: [138],
#  943: [138],
#  944: [138],
#  945: [138],
#  946: [138],
#  947: [138],
#  948: [138],
#  949: [138],
#  950: [138],
#  951: [138],
#  952: [138],
#  953: [138],
#  954: [138],
#  955: [138],
#  956: [138],
#  957: [138],
#  958: [138],
#  959: [138],
#  960: [138],
#  961: [138],
#  962: [138],
#  963: [138],
#  964: [138],
#  965: [138],
#  966: [138],
#  967: [138],
#  968: [138],
#  969: [138],
#  970: [138],
#  971: [138],
#  972: [138],
#  973: [138],
#  974: [138],
#  975: [138],
#  976: [138],
#  977: [138],
#  978: [30],
#  979: [30],
#  980: [30],
#  981: [30],
#  982: [30],
#  983: [30],
#  984: [30],
#  985: [30],
#  986: [30],
#  987: [30],
#  988: [30],
#  989: [30],
#  990: [30],
#  991: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  992: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  993: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  995: [32],
#  996: [32],
#  997: [32],
#  998: [32],
#  999: [32],
#  1000: [32],
#  1001: [32],
#  1002: [32],
#  1003: [32],
#  1004: [32],
#  1006: [32],
#  1007: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1009: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1013: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1014: [31, 439, 167, 101],
#  1015: [31, 439, 167, 101],
#  1016: [31, 439, 167, 101],
#  1017: [31, 439, 167, 101],
#  1018: [31, 439, 167, 101],
#  1019: [32],
#  1020: [4, 906, 179, 178, 97, 74, 37],
#  1021: [4, 906, 179, 178, 97, 74, 37],
#  1022: [4, 906, 179, 178, 97, 74, 37],
#  1023: [4, 906, 179, 178, 97, 74, 37],
#  1024: [53, 90],
#  1025: [53, 90],
#  1026: [53, 90],
#  1027: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1028: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1029: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1030: [53, 90],
#  1031: [53, 90],
#  1032: [53, 90],
#  1033: [53, 90],
#  1034: [138],
#  1035: [1],
#  1036: [1],
#  1037: [1],
#  1038: [1],
#  1039: [53, 90],
#  1040: [53, 90],
#  1041: [58],
#  1042: [3, 567],
#  1043: [3, 567],
#  1044: [3, 567],
#  1045: [3, 567],
#  1046: [3, 567],
#  1047: [3, 567],
#  1048: [3, 567],
#  1049: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1050: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1051: [10, 362, 76],
#  1052: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1058: [4, 906, 179, 178, 97, 74, 37],
#  1059: [4, 906, 179, 178, 97, 74, 37],
#  1060: [4, 906, 179, 178, 97, 74, 37],
#  1061: [4, 906, 179, 178, 97, 74, 37],
#  1062: [4, 906, 179, 178, 97, 74, 37],
#  1063: [4, 906, 179, 178, 97, 74, 37],
#  1064: [4, 906, 179, 178, 97, 74, 37],
#  1066: [22],
#  1067: [22],
#  1068: [22],
#  1069: [22],
#  1070: [22],
#  1071: [22],
#  1072: [22],
#  1073: [22],
#  1074: [22],
#  1075: [22],
#  1076: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1077: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1078: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1079: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1080: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1081: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1082: [2,
#   504,
#   232,
#   177,
#   176,
#   172,
#   171,
#   130,
#   118,
#   117,
#   102,
#   92,
#   86,
#   79,
#   77,
#   46],
#  1083: [1],
#  1084: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1085: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1086: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1087: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1088: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1089: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1090: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1091: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1092: [30],
#  1093: [30],
#  1094: [30],
#  1095: [30],
#  1096: [30],
#  1097: [30],
#  1098: [30],
#  1099: [30],
#  1100: [30],
#  1101: [30],
#  1102: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1105: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1106: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1107: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1108: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1110: [47],
#  1111: [47],
#  1113: [47],
#  1116: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1117: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1118: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1119: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1120: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1121: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1122: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1123: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1124: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1125: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1126: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1127: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1128: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1129: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1130: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1131: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1133: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1135: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1136: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1138: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1140: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1141: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1142: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1143: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1144: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1145: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1146: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1147: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1148: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1149: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1150: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1151: [37],
#  1152: [37],
#  1153: [37],
#  1154: [37],
#  1155: [37],
#  1156: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1157: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1158: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1159: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1160: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1161: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1162: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1163: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1164: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1165: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1166: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1167: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1168: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1169: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1170: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1171: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1172: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1173: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1174: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1175: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1176: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1177: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1178: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1179: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1180: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1181: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1182: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1183: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1184: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1185: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1186: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1187: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1188: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1189: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1190: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1191: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1192: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1193: [17, 180, 103, 94, 49, 33],
#  1194: [17, 180, 103, 94, 49, 33],
#  1195: [17, 180, 103, 94, 49, 33],
#  1196: [17, 180, 103, 94, 49, 33],
#  1197: [17, 180, 103, 94, 49, 33],
#  1198: [17, 180, 103, 94, 49, 33],
#  1199: [17, 180, 103, 94, 49, 33],
#  1201: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1202: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1203: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1204: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1205: [30],
#  1206: [30],
#  1207: [30],
#  1208: [30],
#  1209: [30],
#  1210: [30],
#  1211: [30],
#  1212: [30],
#  1214: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1215: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1218: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1219: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1220: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1221: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1222: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1223: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1224: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1225: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1226: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1227: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1228: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1229: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1230: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1231: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1232: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1233: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1234: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1235: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1236: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1237: [38, 514, 456, 250, 247, 224, 186, 125, 47, 41, 32, 30, 22, 6, 1],
#  1238: [15,
#   695,
#   495,
#   468,
#   337,
#   297,
#   296,
#   286,
#   236,
#   185,
#   184,
#   183,
#   182,
#   181,
#   42],
#  1240: [12, 440, 359, 314, 98, 88, 85, 70, 66, 58, 45, 36, 31, 27, 26, 25],
#  1241: [32],
#  1242: [32],
#  1243: [32],
#  1244: [32],
#  1245: [32],
#  1246: [32],
#  1247: [32],
#  1248: [32],
#  1249: [32],
#  1250: [32],
#  1251: [32],
#  1252: [32],
#  1253: [32],
#  1254: [32],
#  1255: [32],
#  1256: [32],
#  1257: [32],
#  1258: [32],
#  1259: [32],
#  1260: [32],
#  1261: [32],
#  1262: [32],
#  1263: [32],
#  1264: [32],
#  1265: [32],
#  1266: [32],
#  1267: [32],
#  1268: [32],
#  1269: [32],
#  1270: [25, 111, 109, 89, 71, 64],
#  1271: [25, 111, 109, 89, 71, 64],
#  1272: [25, 111, 109, 89, 71, 64],
#  1273: [25, 111, 109, 89, 71, 64],
#  1274: [25, 111, 109, 89, 71, 64],
#  1275: [25, 111, 109, 89, 71, 64],
#  1276: [22],
#  1277: [22],
#  1278: [22],
#  ...}

# %%
## Get complete genre structure
def get_all_structure(estrutura,df_genres):
    ## Get structure from df_genres
    
    def get_all_structure_from_df(estrutura,df_genres):
        if estrutura == 0:
            return 
        else:
            return f'{estrutura}-{get_all_structure_from_df(df_genres[df_genres["genre_id"]==int(estrutura)].parent.values[0],df_genres)}'
        
    
    return get_all_structure_from_df(estrutura,df_genres)

# %%
tracks_df['first_genre_id'] = tracks_df.valid_genre.apply(lambda x:x[0] if x != None else None)

# %%
tracks_df = tracks_df[['valid_genre','first_genre_id']]

# %%
tracks_df
# Out:
#             valid_genre first_genre_id
#
# track_id
# 2                  [21]             21
# 3                  [21]             21
# 5                  [21]             21
# 10                 [10]             10
# 20            [76, 103]             76
# ...                 ...            ...
# 155316             [25]             25
# 155317             [25]             25
# 155318             [25]             25
# 155319             [25]             25
# 155320    [10, 12, 169]             10
#
# [106574 rows x 2 columns]

# %%
tracks_df.dropna(inplace=True)
# Out:
# /tmp/ipykernel_3020699/2764387668.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tracks_df.dropna(inplace=True)

# %%
tracks_df
# Out:
#             valid_genre first_genre_id
#
# track_id
# 2                  [21]             21
# 3                  [21]             21
# 5                  [21]             21
# 10                 [10]             10
# 20            [76, 103]             76
# ...                 ...            ...
# 155316             [25]             25
# 155317             [25]             25
# 155318             [25]             25
# 155319             [25]             25
# 155320    [10, 12, 169]             10
#
# [104343 rows x 2 columns]

# %%
tracks_df["full_genre_id"] = tracks_df.first_genre_id.apply(lambda x: get_all_structure(x,genres_df))
# Out:
# /tmp/ipykernel_3020699/562449490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tracks_df["full_genre_id"] = tracks_df.first_genre_id.apply(lambda x: get_all_structure(x,genres_df))

# %%
tracks_df.reset_index(inplace=True)

# %%
def find_path(track_id,dataset_path):
    track_id = track_id.zfill(6)
    folder_id = track_id[0:3]
    file_path = os.path.join(dataset_path,folder_id,track_id+'.mp3')
    return file_path

# %%
tracks_df['file_path'] = tracks_df.track_id.apply(lambda x: find_path(str(x),args.dataset_path))
# Out:
# /tmp/ipykernel_3020699/3965520815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tracks_df['file_path'] = tracks_df.track_id.apply(lambda x: find_path(str(x),args.dataset_path))

# %%
tracks_df.iloc[0].file_path
# Out:
#     /mnt/disks/data/fma/fma_large/000/000002.mp3
# Name: 0, dtype: object

# %%
def valid_music(file_path):
    try:
        # we start by instantiating the audio loader:
        loader = MonoLoader(filename=file_path)

        return True
    except:
        return False

# %%
valid_music('/mnt/disks/data/fma/fma_large/000/000002.mp3')

# %%
teste = tracks_df.iloc[:100].file_path.astype(str).progress_apply(lambda x: valid_music(x))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
teste
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
# Name: file_path, Length: 100, dtype: bool

# %%
tracks_df[['track_id','file_path']].shape

# %%
tracks_df.shape

# %%
# tracks_df.set_index('track_id',inplace=True)

# %% [markdown]
# ### Delete all crashed files

# %%
tracks_df = tracks_df[tracks_df['Valid'] == True]

# %%
tracks_df.to_csv(os.path.join(train_path,"tracks_genres_id_full_valid.csv"),index=False)

# %%
df = pd.read_csv(os.path.join(train_path,"tracks_genres_id_full_valid.csv"))

# %% [markdown]
# ### Parse of label to structure

# %%
### Function for parse label to sctructure of hierarhical scheme

def parse_label(label):
    label = label.split('-')
    # preencher com 0 no caso de haver menos de 5 níveis
    labels = np.zeros(5,dtype=int)
    for i, label in enumerate(label):
        if i == 5:
            break
        # Aqui você pode fazer a conversão do label em um índice inteiro usando um dicionário ou outro método
        # Neste exemplo, estou apenas usando a posição da label na lista como índice
        labels[i] = label
    return labels

# %%
df.full_genre_id.value_counts()
# Out:
# 15          20307
# 1-38         8678
# 38           6692
# 12           6635
# 10           5906
#             ...
# 444-5           2
# 810-13          2
# 502-46-2        2
# 173-86-2        1
# 170-13          1
# Name: full_genre_id, Length: 148, dtype: int64

# %%
df['labels'] = df.full_genre_id.apply(lambda x: parse_label(x))

# %%
def convert_label_to_string(x,level=2):
    return '-'.join([str(value) for value in x[:level]])

# %%
df['labels_1'] = df.labels.progress_apply(lambda x: str(x[:1][0]))
df['labels_2'] = df.labels.progress_apply(lambda x: convert_label_to_string(x,level=2))
df['labels_3'] = df.labels.progress_apply(lambda x: convert_label_to_string(x,level=3))
df['labels_4'] = df.labels.progress_apply(lambda x: convert_label_to_string(x,level=4))
df['labels_5'] = df.labels.progress_apply(lambda x: convert_label_to_string(x,level=5))
# Out:
#   0%|          | 0/104186 [00:00<?, ?it/s]
#   0%|          | 0/104186 [00:00<?, ?it/s]
#   0%|          | 0/104186 [00:00<?, ?it/s]
#   0%|          | 0/104186 [00:00<?, ?it/s]
#   0%|          | 0/104186 [00:00<?, ?it/s]

# %%
df.labels_2.unique()
# Out:
# array(['21-0', '10-0', '76-10', '45-12', '1-38', '17-0', '4-0', '25-12',
#        '26-12', '30-38', '27-12', '15-0', '12-0', '31-12', '32-38',
#        '89-25', '36-12', '3-0', '37-4', '41-38', '43-65', '79-2', '46-2',
#        '11-14', '38-0', '2-0', '47-38', '33-17', '49-17', '250-38',
#        '138-20', '53-45', '58-12', '22-38', '103-17', '64-25', '66-12',
#        '42-15', '70-12', '71-25', '5-0', '98-12', '74-4', '85-12',
#        '166-65', '188-20', '63-9', '9-0', '118-2', '111-25', '109-25',
#        '97-4', '117-2', '92-2', '77-2', '13-0', '137-9', '102-2', '8-0',
#        '185-15', '101-31', '224-38', '94-17', '20-0', '125-38', '180-17',
#        '113-26', '7-20', '100-21', '906-4', '14-0', '538-18', '6-38',
#        '107-1235', '18-1235', '286-15', '236-15', '90-53', '88-12',
#        '297-15', '65-20', '337-15', '86-2', '763-16', '314-12', '167-31',
#        '172-2', '179-4', '214-92', '19-14', '184-15', '181-15', '359-12',
#        '361-109', '362-10', '183-15', '374-20', '81-92', '322-5',
#        '240-297', '186-38', '187-5', '440-12', '247-38', '171-2',
#        '311-13', '296-15', '468-15', '182-15', '495-15', '130-2',
#        '1060-46', '443-5', '16-6', '542-21', '491-468', '456-38',
#        '514-38', '169-9', '404-85', '177-2', '1193-763', '741-130',
#        '524-130', '360-6', '808-46', '659-5', '400-182', '189-65',
#        '811-21', '539-21', '439-31', '1235-0', '810-13', '442-5', '651-9',
#        '267-1235', '83-21', '504-2', '695-15', '378-20', '428-20',
#        '602-79', '444-5', '1032-102', '502-46', '173-86', '170-13'],
#       dtype=object)

# %%
labels_level_1 = df.labels_1.unique()
labels_level_2 = df.labels_2.unique()
labels_level_3 = df.labels_3.unique()
labels_level_4 = df.labels_4.unique()
labels_level_5 = df.labels_5.unique()

# %%
categories_df = pd.DataFrame(
    {'level5':labels_level_5,
    'level4':labels_level_4,
    'level3':labels_level_3,
    'level2':labels_level_2,
    'level1':labels_level_1})

# %%
def get_labels_name(x,genres_df):
    levels = 5
    full_name = []
    last_level = 0
    genre_root = ""
    for genre in x.split('-'):
        genre_df = genres_df[genres_df['genre_id'] == int(genre)]
        if genre_df.empty:
            genre_name = genre_root 
        else:
            genre_name = genre_df.title.values.tolist()[0]
            genre_root = genre_name
        
        full_name.append(genre_name)
    full_name = '>'.join(full_name)
        
    return full_name
    # return genres_df[genres_df['genre_id'] == int(x)].title.values.tolist()[0]

# %%
categories_df['level5_name'] = categories_df.level5.apply(lambda x: get_labels_name(x,genres_df))

# %%
categories_df['level5_name']
# Out:
# 0                Hip-Hop>Hip-Hop>Hip-Hop>Hip-Hop>Hip-Hop
# 1                                    Pop>Pop>Pop>Pop>Pop
# 2                       Experimental Pop>Pop>Pop>Pop>Pop
# 3                          Loud-Rock>Rock>Rock>Rock>Rock
# 4      Avant-Garde>Experimental>Experimental>Experime...
#                              ...
# 143     Symphony>Classical>Classical>Classical>Classical
# 144    Turkish>Middle East>International>Internationa...
# 145    Cumbia>Latin America>International>Internation...
# 146    N. Indian Traditional>Indian>International>Int...
# 147    Easy Listening: Vocal>Easy Listening>Easy List...
# Name: level5_name, Length: 148, dtype: object

# %%
def __create_labels__(categories_df):
    data = {
        "label1": {},
        "label2": {},
        "label3": {},
        "label4": {},
        "label5": {},
        "label1_inverse": [],
        "label2_inverse": [],
        "label3_inverse": [],
        "label4_inverse": [],
        "label5_inverse": [],
        "label1_name": {},
        "label2_name": {},
        "label3_name": {},
        "label4_name": {},
        "label5_name": {},
    }

    for idx, cat in enumerate(set(categories_df.level1.values.tolist())):
        data['label1'][cat] = idx
        data['label1_inverse'].append(cat)
        data['label1_count'] = idx + 1

    for idx, cat in enumerate(set(categories_df.level2.values.tolist())):
        data['label2'][cat] = idx
        data['label2_inverse'].append(cat)
        data['label2_count'] = idx + 1
        
    for idx, cat in enumerate(set(categories_df.level3.values.tolist())):
        data['label3'][cat] = idx
        data['label3_inverse'].append(cat)
        data['label3_count'] = idx + 1

    for idx, cat in enumerate(set(categories_df.level4.values.tolist())):
        data['label4'][cat] = idx
        data['label4_inverse'].append(cat)
        data['label4_count'] = idx + 1
        
    for idx, cat in enumerate(set(categories_df.level5.values.tolist())):
        data['label5'][cat] = idx
        data['label5_inverse'].append(cat)
        data['label5_count'] = idx + 1
        
    for cat5,cat4,cat3,cat2,cat1,name5 in categories_df.values:
        
        name1 = '>'.join(name5.split('>')[:1])
        name2 = '>'.join(name5.split('>')[:2])
        name3 = '>'.join(name5.split('>')[:3])
        name4 = '>'.join(name5.split('>')[:4])
        
        
        data['label1_name'][cat1] = name1
        data['label2_name'][cat2] = name2
        data['label3_name'][cat3] = name3
        data['label4_name'][cat4] = name4
        data['label5_name'][cat5] = name5
        
    return data

# %%
with open(categories_labels_path, 'w+') as f:
    f.write(json.dumps(__create_labels__(categories_df)))
