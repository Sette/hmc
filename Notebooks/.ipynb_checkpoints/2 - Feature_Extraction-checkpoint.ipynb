I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:33.626234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:33.626313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:33.627895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:33.629502: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)

# %%
base_path = "/mnt/disks/data/fma"

# %%
model_name = "msd-musicnn-1.pb"

# %%
model_path = os.path.join("/home/jupyter/models",model_name)

# %%
metadata_path = os.path.join(base_path,"fma_metadata")

# %%
df = pd.read_csv(os.path.join(metadata_path,"tracks_genres_id_full.csv"))

# %%
df
# Out:
#         track_id  comments         date_created        date_released engineer  \
# 0              2       0.0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 1              3       0.0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 2              5       0.0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3             10       0.0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 4             20       0.0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
# ...          ...       ...                  ...                  ...      ...
# 106569    155316       0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 106570    155317       0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 106571    155318       0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 106572    155319       0.0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 106573    155320       0.0  2017-03-26 16:22:18  2017-03-26 00:00:00      NaN
#
#         favorites       id                                        information  \
# 0             4.0      1.0                                            <p></p>
# 1             4.0      1.0                                            <p></p>
# 2             4.0      1.0                                            <p></p>
# 3             4.0      6.0                                                NaN
# 4             2.0      4.0          <p> "spiritual songs" from Nicky Cook</p>
# ...           ...      ...                                                ...
# 106569        0.0  22940.0  <p>A live performance at Monty Hall on Feb 17,...
# 106570        0.0  22940.0  <p>A live performance at Monty Hall on Feb 17,...
# 106571        0.0  22940.0  <p>A live performance at Monty Hall on Feb 17,...
# 106572        0.0  22940.0  <p>A live performance at Monty Hall on Feb 17,...
# 106573        1.0  22906.0                                                NaN
#
#         listens     producer  ... listens.1 lyricist  number publisher  \
# 0        6073.0          NaN  ...    1293.0      NaN     3.0       NaN
# 1        6073.0          NaN  ...     514.0      NaN     4.0       NaN
# 2        6073.0          NaN  ...    1151.0      NaN     6.0       NaN
# 3       47632.0          NaN  ...   50135.0      NaN     1.0       NaN
# 4        2710.0          NaN  ...     361.0      NaN     3.0       NaN
# ...         ...          ...  ...       ...      ...     ...       ...
# 106569   1506.0  Monty Hall   ...     102.0      NaN     3.0       NaN
# 106570   1506.0  Monty Hall   ...     165.0      NaN     4.0       NaN
# 106571   1506.0  Monty Hall   ...     168.0      NaN     6.0       NaN
# 106572   1506.0  Monty Hall   ...     294.0      NaN     5.0       NaN
# 106573   7481.0          NaN  ...     705.0      NaN     7.0       NaN
#
#                                                    tags.2  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 106569                                                 []
# 106570                                                 []
# 106571                                                 []
# 106572                                                 []
# 106573  ['ballad', 'epic', 'rockabilly', 'curse', 'hex...
#
#                                           title.1 first_genre_id  \
# 0                                            Food             21
# 1                                    Electric Ave             21
# 2                                      This World             21
# 3                                         Freeway             10
# 4                                 Spiritual Level             76
# ...                                           ...            ...
# 106569                                  The Auger             25
# 106570                            Let's Skin Ruby             25
# 106571         My House Smells Like Kim Deal/Pulp             25
# 106572                    The Man With Two Mouths             25
# 106573  Another Trick Up My Sleeve (Instrumental)             10
#
#        full_genre_id                                     file_path  \
# 0               21-0  /mnt/disks/data/fma/fma_large/000/000002.mp3
# 1               21-0  /mnt/disks/data/fma/fma_large/000/000003.mp3
# 2               21-0  /mnt/disks/data/fma/fma_large/000/000005.mp3
# 3               10-0  /mnt/disks/data/fma/fma_large/000/000010.mp3
# 4            76-10-0  /mnt/disks/data/fma/fma_large/000/000020.mp3
# ...              ...                                           ...
# 106569       25-12-0  /mnt/disks/data/fma/fma_large/155/155316.mp3
# 106570       25-12-0  /mnt/disks/data/fma/fma_large/155/155317.mp3
# 106571       25-12-0  /mnt/disks/data/fma/fma_large/155/155318.mp3
# 106572       25-12-0  /mnt/disks/data/fma/fma_large/155/155319.mp3
# 106573          10-0  /mnt/disks/data/fma/fma_large/155/155320.mp3
#
#        first_genre_id_label
# 0                        21
# 1                        21
# 2                        21
# 3                        10
# 4                        49
# ...                     ...
# 106569                   23
# 106570                   23
# 106571                   23
# 106572                   23
# 106573                   10
#
# [106574 rows x 57 columns]

# %%
### Exemplo de extração de features
audio = MonoLoader(filename=df.iloc[1].file_path, sampleRate=16000)()
model = TensorflowPredictMusiCNN(graphFilename=model_path, output="model/dense/BiasAdd")
activations = model(audio)
# Out:
# 2023-01-09 22:25:36.577965: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.579845: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:36.579958: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.581742: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.583335: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:36.583364: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:36.583370: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:36.583375: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:36.583476: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.585162: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.586798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:36.590967: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.592705: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:36.592782: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.594498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.596089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:36.596111: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:36.596117: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:36.596121: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:36.596204: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.597849: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.599485: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:36.603738: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.605456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:36.605536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.607200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.608862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:36.608880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:36.608886: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:36.608890: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:36.608967: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.610628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.612278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `/home/jupyter/models/msd-musicnn-1.pb`
# 2023-01-09 22:25:36.619907: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.621613: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:36.621727: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.623446: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.625021: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:36.625038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:36.625044: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:36.625048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:36.625124: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.626850: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:36.628480: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:36.671214: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2299995000 Hz
# 2023-01-09 22:25:36.849108: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-01-09 22:25:37.395114: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8200
# 2023-01-09 22:25:38.045685: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-01-09 22:25:38.499325: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-01-09 22:25:39.016710: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.018118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:39.018373: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.019613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.020787: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:39.020810: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:39.020817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:39.020823: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:39.020914: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.022195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.023389: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)

# %%
activations.shape
# Out:
# (19, 200)

# %%
def extract_feature(file_path):
    audio = MonoLoader(filename=df.iloc[1].file_path, sampleRate=16000)()
    model = TensorflowPredictMusiCNN(graphFilename=model_path, output="model/dense/BiasAdd")
    activations = model(audio)
    return activations

# %%
def _bytes_feature(value):
    """Returns a bytes_list from a string / byte."""
    if isinstance(value, type(tf.constant(0))): # if value ist tensor
        value = value.numpy() # get value of tensor
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def _float_feature(value):
  """Returns a floast_list from a float / double."""
  return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))

def _int64_feature(value):
  """Returns an int64_list from a bool / enum / int / uint."""
  return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

def serialize_array(array):
  array = tf.io.serialize_tensor(array)
  return array

# %%
def parse_single_music(music, label):

    #define the dictionary -- the structure -- of our single example
    data = {
        'emb' : _bytes_feature(serialize_array(music)),
        'label' : _int64_feature(label)
    }
    #create an Example, wrapping the single features
    out = tf.train.Example(features=tf.train.Features(feature=data))

    return out

# %%
def write_musics_to_tfr_short(musics, labels, filename:str="musics"):
    filename= filename+".tfrecords"
    writer = tf.io.TFRecordWriter(filename) #create a writer that'll store our data to disk
    count = 0

    for index in tqdm(range(len(musics))):

        #get the data we want to write
        current_music = musics[index] 
        current_label = labels[index]

        current_music = extract_feature(current_music)
        
        out = parse_single_music(music=current_music, label=current_label)
        writer.write(out.SerializeToString())
        count += 1

    writer.close()
    print(f"Wrote {count} elements to TFRecord")
    return count

# %%
X_train, X_test, y_train, y_test = train_test_split(df.file_path.tolist(), df.first_genre_id_label.tolist(), test_size=0.30, random_state=42)

# %%
activations.shape
# Out:
# (19, 200)

# %%
count = write_musics_to_tfr_short(X_test[:100], y_test[:100], filename="fma_test")
# Out:
#   0%|          | 0/31973 [00:00<?, ?it/s]
# 2023-01-09 22:25:39.509820: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.511068: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:39.511194: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.512312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.513356: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:39.513384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:39.513390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:39.513395: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:39.513500: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.514587: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.515646: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:39.519716: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.520841: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:39.520928: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.522079: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.523118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:39.523143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:39.523148: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:39.523153: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:39.523238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.524326: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.525389: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:39.529313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.530410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:39.530501: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.531635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.532696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:39.532719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:39.532724: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:39.532729: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:39.532808: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.533917: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.534960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `/home/jupyter/models/msd-musicnn-1.pb`
# 2023-01-09 22:25:39.542419: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.543526: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:39.543624: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.544677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.545736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:39.545769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:39.545777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:39.545782: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:39.545891: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.547062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.548087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:39.690871: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.692619: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:39.692717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.693951: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.695140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:39.695162: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:39.695167: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:39.695172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:39.695255: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.696523: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:39.697715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:39.701201: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-09 22:25:39.704144: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-01-09 22:25:40.116644: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.117896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:40.118058: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.119181: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.120209: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:40.120240: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:40.120246: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:40.120252: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:40.120358: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.121494: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.122575: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:40.126469: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.127605: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:40.127690: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.128730: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.129777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:40.129802: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:40.129808: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:40.129813: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:40.129909: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.131018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.132115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:40.135514: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.136602: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:40.136682: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.137774: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.138777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:40.138798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:40.138803: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:40.138808: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:40.138892: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.139985: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.141061: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `/home/jupyter/models/msd-musicnn-1.pb`
# 2023-01-09 22:25:40.147561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.148642: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:40.148724: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.149866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.150905: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:40.150932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:40.150938: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:40.150944: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:40.151039: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.152175: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.153184: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:40.292024: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.293388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:40.293518: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.294810: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.296395: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:40.296415: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:40.296421: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:40.296426: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:40.296517: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.297804: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.299030: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:40.689209: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.690472: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:40.690627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.691799: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.692894: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:40.692922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:40.692928: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:40.692933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:40.693021: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.694132: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.695193: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:40.699071: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.700173: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:40.700253: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.701534: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.702648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:40.702675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:40.702681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:40.702686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:40.702784: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.703872: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.704916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13632 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2023-01-09 22:25:40.708692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.709796: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.56GiB deviceMemoryBandwidth: 298.08GiB/s
# 2023-01-09 22:25:40.709879: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.710954: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 22:25:40.712024: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-09 22:25:40.712057: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-09 22:25:40.712064: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-09 22:25:40.712069: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-09 22:25:40.712163: I tensorflow/strea

# %%
X_train = [extract_feature(path) for path in X_train]

# %%
X_test = [extract_feature(path) for path in X_test]
