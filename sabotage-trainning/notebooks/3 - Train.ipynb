# %%
import os
import json
import tensorflow as tf
import pandas as pd

from tqdm.notebook import tqdm

# %%
args = pd.Series({
    "root_dir":"/mnt/disks/data/",
    "dataset_path":"/mnt/disks/data/fma/fma_large",
    "embeddings":"music_style",
    "train_id": "hierarchical_sample_test"
})

# %%
job_path = "/mnt/disks/data/fma/trains"


# In[15]:


train_path = os.path.join(job_path,args.train_id)


# In[16]:


base_path = os.path.join(args.root_dir,"fma")


# In[17]:


models_path = os.path.join(args.root_dir,"models")


metadata_path_fma = os.path.join(base_path,"fma_metadata")


# In[18]:


metadata_file = os.path.join(train_path,"metadata.json")


labels_file = os.path.join(train_path,"labels.json")

# %%
def __load_json__(path):
    with open(path, 'r') as f:
        tmp = json.loads(f.read())

    return tmp

# %%
import tensorflow as tf
import multiprocessing



class Dataset:
    def __init__(self, tfrecords_path, epochs, batch_size):
        self.tfrecords_path = tfrecords_path
        self.epochs = epochs
        self.batch_size = batch_size

    def list_files(self):
        return [os.path.join(tfrecords_path,file_path) for file_path in os.listdir(tfrecords_path)]

    def build(self):
        files = self.list_files()

        print("build_tf record: files_count: {} / batch_size: {} / epochs: {}".format(len(files), self.batch_size, self.epochs))

        ds = tf.data.TFRecordDataset(files, num_parallel_reads=multiprocessing.cpu_count())
                      

        return ds
    
   
    @staticmethod
    def __parse__(example):
        parsed = tf.parse_single_example(example, features={
            'emb' : tf.io.FixedLenFeature([], tf.string),
            'track_id' : tf.io.FixedLenSequenceFeature([], tf.int64, allow_missing=True)
        })
        
        content = tf.io.parse_single_example(element, data)

        label = tf.cast(content['track_id'], tf.int32)
        label_hot = tf.one_hot(label1[0], label1[1])
        
        emb = content['emb']
        #get our 'feature'
        feature = tf.io.parse_tensor(emb, out_type=tf.float32)

        inp = {'emb': feature}
        out = {'global_output': label_hot}

        return inp, out

# %%
def _bytes_feature(value):
    """Returns a bytes_list from a string / byte."""
    if isinstance(value, type(tf.constant(0))): # if value ist tensor
        value = value.numpy() # get value of tensor
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def _float_feature(value):
  """Returns a floast_list from a float / double."""
  return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))

def _int64_feature(value):
  """Returns an int64_list from a bool / enum / int / uint."""
  return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

def serialize_array(array):
  array = tf.io.serialize_tensor(array)
  return array



def parser(serialized_example):
    features_description = {'emb': tf.io.FixedLenFeature([], tf.string)}
    features = tf.io.parse_single_example(serialized_example, features_description)
    features = tf.io.decode_raw(features['emb'], tf.float32)
    return features


def parse_tfr_element(element):
    #use the same structure as above; it's kinda an outline of the structure we now want to create
    data = {
        'emb' : tf.io.FixedLenFeature([], tf.string),
        'track_id' : tf.io.FixedLenFeature([], tf.int64),
    }
    
    content = tf.io.parse_single_example(element, data)

    track_id = content['track_id']
    emb = content['emb']
    

    #get our 'feature'-- our image -- and reshape it appropriately
    feature = tf.io.parse_tensor(emb, out_type=tf.float32)
    return (feature, track_id)


def get_dataset(filename):
    #create the dataset
    dataset = tf.data.TFRecordDataset(filename)

    #pass every single feature through our mapping function
    dataset = dataset.map(
        parse_tfr_element
    )

    return dataset

# %%
import numpy as np


def load_dataset(path,dataset=args.embeddings):
    tfrecords_path = os.path.join(path,'tfrecords',dataset)
    
    
    tfrecords_path = [os.path.join(tfrecords_path,path) for path in os.listdir(tfrecords_path)]
    dataset = get_dataset(tfrecords_path)
    
    df = pd.DataFrame(
        dataset.as_numpy_iterator(),
        columns=['feature', 'track_id']
    )
        
    df.dropna(inplace=True)
    
    
    try:
        df.feature = df.feature.apply(lambda x: x[0] if x.shape[0] != 0 else None)
    except:
        print(x)
    
    return df

# %%
df = load_dataset(args.dataset_path,dataset=args.embeddings)

# %%
df
# Out:
#                                                   feature  track_id
# 0       [0.0008698702, 0.008201729, 0.018753221, -0.03...    124573
# 1       [-0.00097459555, -0.0051385164, -0.024011323, ...    124574
# 2       [0.039855253, 0.0076441965, -0.00922821, -0.04...    124575
# 3       [0.0029335518, 0.020818433, 0.04269241, -0.016...    124576
# 4       [0.057992022, -0.0510619, -0.048113894, -0.032...    124577
# ...                                                   ...       ...
# 104181  [-0.0080008805, 6.110469e-05, 0.18494046, 0.02...     94245
# 104182  [0.017404526, 0.0132987695, 0.004312843, 0.048...     94246
# 104183  [0.01726994, 0.005624622, 0.10627997, 0.007201...     94247
# 104184  [0.07001238, -3.400445e-05, 0.03528729, 0.0683...     94248
# 104185  [-0.013616562, -0.012981772, -0.0065422454, -0...     94249
#
# [104186 rows x 2 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                                                   feature  track_id
# 0       [0.0008698702, 0.008201729, 0.018753221, -0.03...    124573
# 1       [-0.00097459555, -0.0051385164, -0.024011323, ...    124574
# 2       [0.039855253, 0.0076441965, -0.00922821, -0.04...    124575
# 3       [0.0029335518, 0.020818433, 0.04269241, -0.016...    124576
# 4       [0.057992022, -0.0510619, -0.048113894, -0.032...    124577
# ...                                                   ...       ...
# 104181  [-0.0080008805, 6.110469e-05, 0.18494046, 0.02...     94245
# 104182  [0.017404526, 0.0132987695, 0.004312843, 0.048...     94246
# 104183  [0.01726994, 0.005624622, 0.10627997, 0.007201...     94247
# 104184  [0.07001238, -3.400445e-05, 0.03528729, 0.0683...     94248
# 104185  [-0.013616562, -0.012981772, -0.0065422454, -0...     94249
#
# [104170 rows x 2 columns]

# %%
tracks_df = pd.read_csv(os.path.join(train_path,"tracks.csv"))

# %%
labels = __load_json__(labels_file)

# %%
labels
# Out:
# {'label1': {'17': 0,
#   '2': 1,
#   '20': 2,
#   '10': 3,
#   '13': 4,
#   '9': 5,
#   '21': 6,
#   '3': 7,
#   '8': 8,
#   '4': 9,
#   '38': 10,
#   '5': 11,
#   '14': 12,
#   '1235': 13,
#   '12': 14,
#   '15': 15},
#  'label2': {'8-0': 0,
#   '2-130': 1,
#   '12-27': 2,
#   '38-125': 3,
#   '5-444': 4,
#   '4-97': 5,
#   '17-49': 6,
#   '21-580': 7,
#   '9-169': 8,
#   '20-378': 9,
#   '38-41': 10,
#   '21-811': 11,
#   '38-514': 12,
#   '12-440': 13,
#   '38-247': 14,
#   '10-76': 15,
#   '38-47': 16,
#   '2-118': 17,
#   '12-58': 18,
#   '12-66': 19,
#   '4-37': 20,
#   '15-286': 21,
#   '20-65': 22,
#   '5-187': 23,
#   '38-186': 24,
#   '38-456': 25,
#   '21-83': 26,
#   '10-0': 27,
#   '12-26': 28,
#   '12-314': 29,
#   '2-46': 30,
#   '10-362': 31,
#   '13-170': 32,
#   '9-137': 33,
#   '9-63': 34,
#   '4-179': 35,
#   '21-693': 36,
#   '20-0': 37,
#   '38-32': 38,
#   '12-0': 39,
#   '4-0': 40,
#   '9-0': 41,
#   '4-74': 42,
#   '14-19': 43,
#   '21-539': 44,
#   '2-86': 45,
#   '2-77': 46,
#   '15-236': 47,
#   '20-138': 48,
#   '12-98': 49,
#   '2-177': 50,
#   '14-0': 51,
#   '1235-0': 52,
#   '12-88': 53,
#   '38-250': 54,
#   '38-224': 55,
#   '15-337': 56,
#   '21-542': 57,
#   '12-359': 58,
#   '5-0': 59,
#   '15-0': 60,
#   '21-0': 61,
#   '12-31': 62,
#   '2-504': 63,
#   '38-6': 64,
#   '14-11': 65,
#   '2-117': 66,
#   '2-171': 67,
#   '15-495': 68,
#   '12-36': 69,
#   '5-442': 70,
#   '4-906': 71,
#   '20-188': 72,
#   '5-659': 73,
#   '13-0': 74,
#   '5-322': 75,
#   '15-297': 76,
#   '15-185': 77,
#   '38-1': 78,
#   '2-102': 79,
#   '15-184': 80,
#   '13-311': 81,
#   '12-25': 82,
#   '1235-18': 83,
#   '15-468': 84,
#   '17-94': 85,
#   '17-0': 86,
#   '15-695': 87,
#   '17-180': 88,
#   '15-182': 89,
#   '38-0': 90,
#   '20-374': 91,
#   '38-30': 92,
#   '15-181': 93,
#   '2-92': 94,
#   '13-810': 95,
#   '5-441': 96,
#   '20-428': 97,
#   '15-42': 98,
#   '2-172': 99,
#   '2-176': 100,
#   '3-567': 101,
#   '1235-267': 102,
#   '2-0': 103,
#   '3-0': 104,
#   '15-183': 105,
#   '12-45': 106,
#   '2-232': 107,
#   '1235-107': 108,
#   '38-22': 109,
#   '17-33': 110,
#   '15-296': 111,
#   '17-103': 112,
#   '12-70': 113,
#   '9-651': 114,
#   '2-79': 115,
#   '12-85': 116,
#   '21-100': 117,
#   '5-443': 118},
#  'label3': {'13-810-0': 0,
#   '5-442-0': 1,
#   '8-0-0': 2,
#   '38-247-0': 3,
#   '1235-267-0': 4,
#   '21-542-0': 5,
#   '12-66-0': 6,
#   '12-25-0': 7,
#   '21-100-0': 8,
#   '15-42-0': 9,
#   '12-0-0': 10,
#   '2-79-602': 11,
#   '9-137-0': 12,
#   '2-177-0': 13,
#   '14-19-0': 14,
#   '4-37-0': 15,
#   '12-26-113': 16,
#   '15-0-0': 17,
#   '2-102-0': 18,
#   '13-311-0': 19,
#   '3-0-0': 20,
#   '15-297-240': 21,
#   '2-46-0': 22,
#   '12-26-0': 23,
#   '2-77-0': 24,
#   '15-181-401': 25,
#   '12-45-0': 26,
#   '9-169-0': 27,
#   '2-92-0': 28,
#   '21-693-0': 29,
#   '38-41-0': 30,
#   '2-130-619': 31,
#   '15-183-0': 32,
#   '12-25-109': 33,
#   '38-456-0': 34,
#   '10-362-0': 35,
#   '17-103-0': 36,
#   '10-76-0': 37,
#   '21-539-0': 38,
#   '12-31-0': 39,
#   '2-46-1060': 40,
#   '2-0-0': 41,
#   '2-232-0': 42,
#   '20-378-0': 43,
#   '38-6-0': 44,
#   '12-25-89': 45,
#   '9-651-0': 46,
#   '2-130-524': 47,
#   '12-98-0': 48,
#   '4-0-0': 49,
#   '2-130-741': 50,
#   '38-30-0': 51,
#   '1235-0-0': 52,
#   '21-811-0': 53,
#   '15-695-0': 54,
#   '12-25-64': 55,
#   '1235-107-0': 56,
#   '5-441-0': 57,
#   '20-0-0': 58,
#   '4-74-0': 59,
#   '1235-18-0': 60,
#   '12-27-0': 61,
#   '2-92-214': 62,
#   '2-92-81': 63,
#   '4-179-0': 64,
#   '12-359-0': 65,
#   '2-130-0': 66,
#   '2-86-174': 67,
#   '15-296-0': 68,
#   '38-32-0': 69,
#   '9-0-0': 70,
#   '20-65-0': 71,
#   '17-49-0': 72,
#   '15-286-0': 73,
#   '2-79-0': 74,
#   '2-86-0': 75,
#   '2-172-0': 76,
#   '20-65-166': 77,
#   '20-65-43': 78,
#   '12-88-0': 79,
#   '20-428-0': 80,
#   '15-182-0': 81,
#   '38-47-0': 82,
#   '20-188-0': 83,
#   '1235-18-538': 84,
#   '12-25-71': 85,
#   '12-440-0': 86,
#   '38-22-0': 87,
#   '15-185-0': 88,
#   '2-46-808': 89,
#   '38-6-16': 90,
#   '38-6-360': 91,
#   '4-906-0': 92,
#   '38-224-0': 93,
#   '15-182-400': 94,
#   '17-33-0': 95,
#   '14-0-0': 96,
#   '15-495-0': 97,
#   '12-314-0': 98,
#   '38-250-0': 99,
#   '5-659-0': 100,
#   '2-130-1156': 101,
#   '2-171-0': 102,
#   '15-468-0': 103,
#   '5-322-0': 104,
#   '17-94-0': 105,
#   '5-443-0': 106,
#   '20-138-0': 107,
#   '2-176-0': 108,
#   '15-236-0': 109,
#   '17-180-0': 110,
#   '14-11-0': 111,
#   '15-181-0': 112,
#   '3-567-0': 113,
#   '12-31-439': 114,
#   '2-46-502': 115,
#   '2-117-0': 116,
#   '2-102-1032': 117,
#   '12-25-111': 118,
#   '13-0-0': 119,
#   '4-97-0': 120,
#   '12-70-0': 121,
#   '12-31-167': 122,
#   '38-0-0': 123,
#   '12-36-0': 124,
#   '9-63-0': 125,
#   '5-0-0': 126,
#   '5-444-0': 127,
#   '21-0-0': 128,
#   '13-170-0': 129,
#   '12-45-53': 130,
#   '38-186-0': 131,
#   '15-184-0': 132,
#   '21-83-0': 133,
#   '12-58-0': 134,
#   '20-374-0': 135,
#   '5-187-0': 136,
#   '12-31-101': 137,
#   '2-118-0': 138,
#   '38-125-0': 139,
#   '38-1-0': 140,
#   '17-0-0': 141,
#   '2-504-0': 142,
#   '38-514-0': 143,
#   '10-0-0': 144,
#   '12-85-404': 145,
#   '15-468-491': 146,
#   '15-337-0': 147,
#   '15-297-0': 148,
#   '12-85-0': 149,
#   '21-580-0': 150},
#  'label4': {'38-47-0-0': 0,
#   '38-41-0-0': 1,
#   '9-137-0-0': 2,
#   '38-32-0-0': 3,
#   '17-180-0-0': 4,
#   '4-74-0-0': 5,
#   '38-6-360-0': 6,
#   '20-188-0-0': 7,
#   '20-65-43-0': 8,
#   '5-443-0-0': 9,
#   '12-70-0-0': 10,
#   '2-79-602-0': 11,
#   '2-117-0-0': 12,
#   '38-6-16-763': 13,
#   '1235-107-0-0': 14,
#   '2-130-741-0': 15,
#   '2-0-0-0': 16,
#   '5-322-0-0': 17,
#   '17-0-0-0': 18,
#   '1235-267-0-0': 19,
#   '2-86-174-0': 20,
#   '9-0-0-0': 21,
#   '10-76-0-0': 22,
#   '2-86-0-0': 23,
#   '12-45-53-90': 24,
#   '12-25-111-0': 25,
#   '4-906-0-0': 26,
#   '14-19-0-0': 27,
#   '2-130-0-0': 28,
#   '38-30-0-0': 29,
#   '15-468-491-0': 30,
#   '5-441-0-0': 31,
#   '21-83-0-0': 32,
#   '2-79-0-0': 33,
#   '12-45-0-0': 34,
#   '8-0-0-0': 35,
#   '4-97-0-0': 36,
#   '3-0-0-0': 37,
#   '2-46-502-0': 38,
#   '5-444-0-0': 39,
#   '2-130-524-0': 40,
#   '15-42-0-0': 41,
#   '2-92-214-0': 42,
#   '12-36-0-0': 43,
#   '12-98-0-0': 44,
#   '1235-0-0-0': 45,
#   '2-46-808-0': 46,
#   '20-378-0-0': 47,
#   '15-182-0-0': 48,
#   '12-27-0-0': 49,
#   '38-247-0-0': 50,
#   '21-100-0-0': 51,
#   '2-46-1060-0': 52,
#   '21-811-0-0': 53,
#   '15-0-0-0': 54,
#   '12-66-0-0': 55,
#   '2-92-0-0': 56,
#   '20-138-0-0': 57,
#   '10-0-0-0': 58,
#   '17-94-0-0': 59,
#   '38-224-0-0': 60,
#   '15-297-240-0': 61,
#   '21-580-0-0': 62,
#   '13-0-0-0': 63,
#   '38-186-0-0': 64,
#   '15-297-0-0': 65,
#   '12-85-404-0': 66,
#   '9-651-0-0': 67,
#   '17-33-0-0': 68,
#   '20-65-166-0': 69,
#   '2-232-0-0': 70,
#   '12-440-0-0': 71,
#   '4-179-0-0': 72,
#   '13-311-0-0': 73,
#   '15-337-0-0': 74,
#   '12-26-113-0': 75,
#   '17-103-0-0': 76,
#   '21-693-0-0': 77,
#   '21-0-0-0': 78,
#   '15-695-0-0': 79,
#   '12-26-0-0': 80,
#   '10-362-0-0': 81,
#   '15-468-0-0': 82,
#   '14-11-0-0': 83,
#   '20-0-0-0': 84,
#   '12-31-439-0': 85,
#   '2-130-1156-0': 86,
#   '12-25-64-0': 87,
#   '14-0-0-0': 88,
#   '4-0-0-0': 89,
#   '2-130-619-0': 90,
#   '15-296-0-0': 91,
#   '2-172-0-0': 92,
#   '5-0-0-0': 93,
#   '20-65-0-0': 94,
#   '38-0-0-0': 95,
#   '38-125-0-0': 96,
#   '21-542-0-0': 97,
#   '12-25-109-361': 98,
#   '12-31-0-0': 99,
#   '1235-18-538-0': 100,
#   '12-314-0-0': 101,
#   '12-25-109-0': 102,
#   '9-63-0-0': 103,
#   '12-45-53-0': 104,
#   '5-659-0-0': 105,
#   '1235-18-0-0': 106,
#   '15-181-0-0': 107,
#   '20-428-0-0': 108,
#   '15-181-401-0': 109,
#   '38-1-0-0': 110,
#   '38-456-0-0': 111,
#   '2-46-0-0': 112,
#   '2-171-0-0': 113,
#   '12-31-167-0': 114,
#   '2-504-0-0': 115,
#   '2-177-0-0': 116,
#   '9-169-0-0': 117,
#   '2-176-0-0': 118,
#   '12-85-0-0': 119,
#   '15-236-0-0': 120,
#   '20-374-0-0': 121,
#   '15-183-0-0': 122,
#   '38-22-0-0': 123,
#   '12-0-0-0': 124,
#   '21-539-0-0': 125,
#   '2-77-0-0': 126,
#   '5-442-0-0': 127,
#   '12-25-71-0': 128,
#   '12-359-0-0': 129,
#   '12-25-89-0': 130,
#   '15-185-0-0': 131,
#   '15-184-0-0': 132,
#   '2-118-0-0': 133,
#   '4-37-0-0': 134,
#   '2-102-0-0': 135,
#   '38-6-0-0': 136,
#   '2-92-81-0': 137,
#   '15-182-400-0': 138,
#   '13-810-0-0': 139,
#   '12-31-101-0': 140,
#   '38-514-0-0': 141,
#   '15-495-0-0': 142,
#   '17-49-0-0': 143,
#   '2-102-1032-0': 144,
#   '12-58-0-0': 145,
#   '12-25-0-0': 146,
#   '15-286-0-0': 147,
#   '3-567-0-0': 148,
#   '13-170-0-0': 149,
#   '38-250-0-0': 150,
#   '12-88-0-0': 151,
#   '5-187-0-0': 152},
#  'label5': {'2-102-0-0-0': 0,
#   '38-6-0-0-0': 1,
#   '38-6-16-763-1193': 2,
#   '12-314-0-0-0': 3,
#   '12-359-0-0-0': 4,
#   '2-92-0-0-0': 5,
#   '15-182-400-0-0': 6,
#   '20-428-0-0-0': 7,
#   '12-0-0-0-0': 8,
#   '2-117-0-0-0': 9,
#   '2-118-0-0-0': 10,
#   '12-66-0-0-0': 11,
#   '13-810-0-0-0': 12,
#   '5-443-0-0-0': 13,
#   '38-41-0-0-0': 14,
#   '15-181-0-0-0': 15,
#   '2-130-524-0-0': 16,
#   '2-46-808-0-0': 17,
#   '12-25-64-0-0': 18,
#   '5-442-0-0-0': 19,
#   '15-185-0-0-0': 20,
#   '38-514-0-0-0': 21,
#   '12-70-0-0-0': 22,
#   '15-468-491-0-0': 23,
#   '20-374-0-0-0': 24,
#   '15-182-0-0-0': 25,
#   '15-695-0-0-0': 26,
#   '5-0-0-0-0': 27,
#   '9-137-0-0-0': 28,
#   '38-250-0-0-0': 29,
#   '12-25-71-0-0': 30,
#   '38-0-0-0-0': 31,
#   '10-362-0-0-0': 32,
#   '15-42-0-0-0': 33,
#   '17-33-0-0-0': 34,
#   '2-171-0-0-0': 35,
#   '2-46-1060-0-0': 36,
#   '9-0-0-0-0': 37,
#   '14-11-0-0-0': 38,
#   '13-311-0-0-0': 39,
#   '12-45-53-90-0': 40,
#   '4-906-0-0-0': 41,
#   '12-88-0-0-0': 42,
#   '2-46-0-0-0': 43,
#   '2-86-0-0-0': 44,
#   '3-567-0-0-0': 45,
#   '15-297-240-0-0': 46,
#   '12-36-0-0-0': 47,
#   '4-74-0-0-0': 48,
#   '1235-18-0-0-0': 49,
#   '38-224-0-0-0': 50,
#   '15-236-0-0-0': 51,
#   '12-85-404-0-0': 52,
#   '2-77-0-0-0': 53,
#   '4-97-0-0-0': 54,
#   '2-92-81-0-0': 55,
#   '2-79-0-0-0': 56,
#   '15-468-0-0-0': 57,
#   '2-86-174-0-0': 58,
#   '5-187-0-0-0': 59,
#   '38-32-0-0-0': 60,
#   '12-25-111-0-0': 61,
#   '21-539-0-0-0': 62,
#   '21-811-0-0-0': 63,
#   '15-286-0-0-0': 64,
#   '17-0-0-0-0': 65,
#   '12-25-0-0-0': 66,
#   '12-98-0-0-0': 67,
#   '8-0-0-0-0': 68,
#   '12-27-0-0-0': 69,
#   '38-125-0-0-0': 70,
#   '2-46-502-0-0': 71,
#   '20-65-166-0-0': 72,
#   '5-659-0-0-0': 73,
#   '15-495-0-0-0': 74,
#   '17-49-0-0-0': 75,
#   '2-0-0-0-0': 76,
#   '21-542-0-0-0': 77,
#   '12-31-167-0-0': 78,
#   '2-232-0-0-0': 79,
#   '38-186-0-0-0': 80,
#   '10-76-0-0-0': 81,
#   '12-31-0-0-0': 82,
#   '12-26-0-0-0': 83,
#   '5-322-0-0-0': 84,
#   '20-138-0-0-0': 85,
#   '2-130-1156-0-0': 86,
#   '21-580-0-0-0': 87,
#   '21-100-0-0-0': 88,
#   '12-58-0-0-0': 89,
#   '21-0-0-0-0': 90,
#   '12-26-113-0-0': 91,
#   '12-25-109-0-0': 92,
#   '38-6-360-0-0': 93,
#   '9-651-0-0-0': 94,
#   '2-130-741-0-0': 95,
#   '38-22-0-0-0': 96,
#   '13-170-0-0-0': 97,
#   '20-378-0-0-0': 98,
#   '4-179-0-0-0': 99,
#   '15-184-0-0-0': 100,
#   '2-172-0-0-0': 101,
#   '38-1-0-0-0': 102,
#   '1235-0-0-0-0': 103,
#   '17-180-0-0-0': 104,
#   '2-130-0-0-0': 105,
#   '12-25-109-361-0': 106,
#   '20-65-43-0-0': 107,
#   '38-456-0-0-0': 108,
#   '12-45-53-0-0': 109,
#   '2-504-0-0-0': 110,
#   '12-85-0-0-0': 111,
#   '21-693-0-0-0': 112,
#   '12-45-0-0-0': 113,
#   '4-0-0-0-0': 114,
#   '2-79-602-0-0': 115,
#   '2-176-0-0-0': 116,
#   '20-65-0-0-0': 117,
#   '1235-18-538-0-0': 118,
#   '20-0-0-0-0': 119,
#   '1235-107-0-0-0': 120,
#   '15-183-0-0-0': 121,
#   '2-102-1032-0-0': 122,
#   '9-63-0-0-0': 123,
#   '14-19-0-0-0': 124,
#   '5-444-0-0-0': 125,
#   '38-247-0-0-0': 126,
#   '9-169-0-0-0': 127,
#   '13-0-0-0-0': 128,
#   '15-181-401-0-0': 129,
#   '12-25-89-0-0': 130,
#   '38-6-16-763-0': 131,
#   '15-0-0-0-0': 132,
#   '38-47-0-0-0': 133,
#   '12-440-0-0-0': 134,
#   '12-31-439-0-0': 135,
#   '15-297-0-0-0': 136,
#   '17-103-0-0-0': 137,
#   '15-296-0-0-0': 138,
#   '2-177-0-0-0': 139,
#   '1235-267-0-0-0': 140,
#   '10-0-0-0-0': 141,
#   '2-92-214-0-0': 142,
#   '38-30-0-0-0': 143,
#   '20-188-0-0-0': 144,
#   '17-94-0-0-0': 145,
#   '3-0-0-0-0': 146,
#   '4-37-0-0-0': 147,
#   '2-130-619-0-0': 148,
#   '21-83-0-0-0': 149,
#   '15-337-0-0-0': 150,
#   '5-441-0-0-0': 151,
#   '12-31-101-0-0': 152,
#   '14-0-0-0-0': 153},
#  'label1_inverse': ['17',
#   '2',
#   '20',
#   '10',
#   '13',
#   '9',
#   '21',
#   '3',
#   '8',
#   '4',
#   '38',
#   '5',
#   '14',
#   '1235',
#   '12',
#   '15'],
#  'label2_inverse': ['8-0',
#   '2-130',
#   '12-27',
#   '38-125',
#   '5-444',
#   '4-97',
#   '17-49',
#   '21-580',
#   '9-169',
#   '20-378',
#   '38-41',
#   '21-811',
#   '38-514',
#   '12-440',
#   '38-247',
#   '10-76',
#   '38-47',
#   '2-118',
#   '12-58',
#   '12-66',
#   '4-37',
#   '15-286',
#   '20-65',
#   '5-187',
#   '38-186',
#   '38-456',
#   '21-83',
#   '10-0',
#   '12-26',
#   '12-314',
#   '2-46',
#   '10-362',
#   '13-170',
#   '9-137',
#   '9-63',
#   '4-179',
#   '21-693',
#   '20-0',
#   '38-32',
#   '12-0',
#   '4-0',
#   '9-0',
#   '4-74',
#   '14-19',
#   '21-539',
#   '2-86',
#   '2-77',
#   '15-236',
#   '20-138',
#   '12-98',
#   '2-177',
#   '14-0',
#   '1235-0',
#   '12-88',
#   '38-250',
#   '38-224',
#   '15-337',
#   '21-542',
#   '12-359',
#   '5-0',
#   '15-0',
#   '21-0',
#   '12-31',
#   '2-504',
#   '38-6',
#   '14-11',
#   '2-117',
#   '2-171',
#   '15-495',
#   '12-36',
#   '5-442',
#   '4-906',
#   '20-188',
#   '5-659',
#   '13-0',
#   '5-322',
#   '15-297',
#   '15-185',
#   '38-1',
#   '2-102',
#   '15-184',
#   '13-311',
#   '12-25',
#   '1235-18',
#   '15-468',
#   '17-94',
#   '17-0',
#   '15-695',
#   '17-180',
#   '15-182',
#   '38-0',
#   '20-374',
#   '38-30',
#   '15-181',
#   '2-92',
#   '13-810',
#   '5-441',
#   '20-428',
#   '15-42',
#   '2-172',
#   '2-176',
#   '3-567',
#   '1235-267',
#   '2-0',
#   '3-0',
#   '15-183',
#   '12-45',
#   '2-232',
#   '1235-107',
#   '38-22',
#   '17-33',
#   '15-296',
#   '17-103',
#   '12-70',
#   '9-651',
#   '2-79',
#   '12-85',
#   '21-100',
#   '5-443'],
#  'label3_inverse': ['13-810-0',
#   '5-442-0',
#   '8-0-0',
#   '38-247-0',
#   '1235-267-0',
#   '21-542-0',
#   '12-66-0',
#   '12-25-0',
#   '21-100-0',
#   '15-42-0',
#   '12-0-0',
#   '2-79-602',
#   '9-137-0',
#   '2-177-0',
#   '14-19-0',
#   '4-37-0',
#   '12-26-113',
#   '15-0-0',
#   '2-102-0',
#   '13-311-0',
#   '3-0-0',
#   '15-297-240',
#   '2-46-0',
#   '12-26-0',
#   '2-77-0',
#   '15-181-401',
#   '12-45-0',
#   '9-169-0',
#   '2-92-0',
#   '21-693-0',
#   '38-41-0',
#   '2-130-619',
#   '15-183-0',
#   '12-25-109',
#   '38-456-0',
#   '10-362-0',
#   '17-103-0',
#   '10-76-0',
#   '21-539-0',
#   '12-31-0',
#   '2-46-1060',
#   '2-0-0',
#   '2-232-0',
#   '20-378-0',
#   '38-6-0',
#   '12-25-89',
#   '9-651-0',
#   '2-130-524',
#   '12-98-0',
#   '4-0-0',
#   '2-130-741',
#   '38-30-0',
#   '1235-0-0',
#   '21-811-0',
#   '15-695-0',
#   '12-25-64',
#   '1235-107-0',
#   '5-441-0',
#   '20-0-0',
#   '4-74-0',
#   '1235-18-0',
#   '12-27-0',
#   '2-92-214',
#   '2-92-81',
#   '4-179-0',
#   '12-359-0',
#   '2-130-0',
#   '2-86-174',
#   '15-296-0',
#   '38-32-0',
#   '9-0-0',
#   '20-65-0',
#   '17-49-0',
#   '15-286-0',
#   '2-79-0',
#   '2-86-0',
#   '2-172-0',
#   '20-65-166',
#   '20-65-43',
#   '12-88-0',
#   '20-428-0',
#   '15-182-0',
#   '38-47-0',
#   '20-188-0',
#   '1235-18-538',
#   '12-25-71',
#   '12-440-0',
#   '38-22-0',
#   '15-185-0',
#   '2-46-808',
#   '38-6-16',
#   '38-6-360',
#   '4-906-0',
#   '38-224-0',
#   '15-182-400',
#   '17-33-0',
#   '14-0-0',
#   '15-495-0',
#   '12-314-0',
#   '38-250-0',
#   '5-659-0',
#   '2-130-1156',
#   '2-171-0',
#   '15-468-0',
#   '5-322-0',
#   '17-94-0',
#   '5-443-0',
#   '20-138-0',
#   '2-176-0',
#   '15-236-0',
#   '17-180-0',
#   '14-11-0',
#   '15-181-0',
#   '3-567-0',
#   '12-31-439',
#   '2-46-502',
#   '2-117-0',
#   '2-102-1032',
#   '12-25-111',
#   '13-0-0',
#   '4-97-0',
#   '12-70-0',
#   '12-31-167',
#   '38-0-0',
#   '12-36-0',
#   '9-63-0',
#   '5-0-0',
#   '5-444-0',
#   '21-0-0',
#   '13-170-0',
#   '12-45-53',
#   '38-186-0',
#   '15-184-0',
#   '21-83-0',
#   '12-58-0',
#   '20-374-0',
#   '5-187-0',
#   '12-31-101',
#   '2-118-0',
#   '38-125-0',
#   '38-1-0',
#   '17-0-0',
#   '2-504-0',
#   '38-514-0',
#   '10-0-0',
#   '12-85-404',
#   '15-468-491',
#   '15-337-0',
#   '15-297-0',
#   '12-85-0',
#   '21-580-0'],
#  'label4_inverse': ['38-47-0-0',
#   '38-41-0-0',
#   '9-137-0-0',
#   '38-32-0-0',
#   '17-180-0-0',
#   '4-74-0-0',
#   '38-6-360-0',
#   '20-188-0-0',
#   '20-65-43-0',
#   '5-443-0-0',
#   '12-70-0-0',
#   '2-79-602-0',
#   '2-117-0-0',
#   '38-6-16-763',
#   '1235-107-0-0',
#   '2-130-741-0',
#   '2-0-0-0',
#   '5-322-0-0',
#   '17-0-0-0',
#   '1235-267-0-0',
#   '2-86-174-0',
#   '9-0-0-0',
#   '10-76-0-0',
#   '2-86-0-0',
#   '12-45-53-90',
#   '12-25-111-0',
#   '4-906-0-0',
#   '14-19-0-0',
#   '2-130-0-0',
#   '38-30-0-0',
#   '15-468-491-0',
#   '5-441-0-0',
#   '21-83-0-0',
#   '2-79-0-0',
#   '12-45-0-0',
#   '8-0-0-0',
#   '4-97-0-0',
#   '3-0-0-0',
#   '2-46-502-0',
#   '5-444-0-0',
#   '2-130-524-0',
#   '15-42-0-0',
#   '2-92-214-0',
#   '12-36-0-0',
#   '12-98-0-0',
#   '1235-0-0-0',
#   '2-46-808-0',
#   '20-378-0-0',
#   '15-182-0-0',
#   '12-27-0-0',
#   '38-247-0-0',
#   '21-100-0-0',
#   '2-46-1060-0',
#   '21-811-0-0',
#   '15-0-0-0',
#   '12-66-0-0',
#   '2-92-0-0',
#   '20-138-0-0',
#   '10-0-0-0',
#   '17-94-0-0',
#   '38-224-0-0',
#   '15-297-240-0',
#   '21-580-0-0',
#   '13-0-0-0',
#   '38-186-0-0',
#   '15-297-0-0',
#   '12-85-404-0',
#   '9-651-0-0',
#   '17-33-0-0',
#   '20-65-166-0',
#   '2-232-0-0',
#   '12-440-0-0',
#   '4-179-0-0',
#   '13-311-0-0',
#   '15-337-0-0',
#   '12-26-113-0',
#   '17-103-0-0',
#   '21-693-0-0',
#   '21-0-0-0',
#   '15-695-0-0',
#   '12-26-0-0',
#   '10-362-0-0',
#   '15-468-0-0',
#   '14-11-0-0',
#   '20-0-0-0',
#   '12-31-439-0',
#   '2-130-1156-0',
#   '12-25-64-0',
#   '14-0-0-0',
#   '4-0-0-0',
#   '2-130-619-0',
#   '15-296-0-0',
#   '2-172-0-0',
#   '5-0-0-0',
#   '20-65-0-0',
#   '38-0-0-0',
#   '38-125-0-0',
#   '21-542-0-0',
#   '12-25-109-361',
#   '12-31-0-0',
#   '1235-18-538-0',
#   '12-314-0-0',
#   '12-25-109-0',
#   '9-63-0-0',
#   '12-45-53-0',
#   '5-659-0-0',
#   '1235-18-0-0',
#   '15-181-0-0',
#   '20-428-0-0',
#   '15-181-401-0',
#   '38-1-0-0',
#   '38-456-0-0',
#   '2-46-0-0',
#   '2-171-0-0',
#   '12-31-167-0',
#   '2-504-0-0',
#   '2-177-0-0',
#   '9-169-0-0',
#   '2-176-0-0',
#   '12-85-0-0',
#   '15-236-0-0',
#   '20-374-0-0',
#   '15-183-0-0',
#   '38-22-0-0',
#   '12-0-0-0',
#   '21-539-0-0',
#   '2-77-0-0',
#   '5-442-0-0',
#   '12-25-71-0',
#   '12-359-0-0',
#   '12-25-89-0',
#   '15-185-0-0',
#   '15-184-0-0',
#   '2-118-0-0',
#   '4-37-0-0',
#   '2-102-0-0',
#   '38-6-0-0',
#   '2-92-81-0',
#   '15-182-400-0',
#   '13-810-0-0',
#   '12-31-101-0',
#   '38-514-0-0',
#   '15-495-0-0',
#   '17-49-0-0',
#   '2-102-1032-0',
#   '12-58-0-0',
#   '12-25-0-0',
#   '15-286-0-0',
#   '3-567-0-0',
#   '13-170-0-0',
#   '38-250-0-0',
#   '12-88-0-0',
#   '5-187-0-0'],
#  'label5_inverse': ['2-102-0-0-0',
#   '38-6-0-0-0',
#   '38-6-16-763-1193',
#   '12-314-0-0-0',
#   '12-359-0-0-0',
#   '2-92-0-0-0',
#   '15-182-400-0-0',
#   '20-428-0-0-0',
#   '12-0-0-0-0',
#   '2-117-0-0-0',
#   '2-118-0-0-0',
#   '12-66-0-0-0',
#   '13-810-0-0-0',
#   '5-443-0-0-0',
#   '38-41-0-0-0',
#   '15-181-0-0-0',
#   '2-130-524-0-0',
#   '2-46-808-0-0',
#   '12-25-64-0-0',
#   '5-442-0-0-0',
#   '15-185-0-0-0',
#   '38-514-0-0-0',
#   '12-70-0-0-0',
#   '15-468-491-0-0',
#   '20-374-0-0-0',
#   '15-182-0-0-0',
#   '15-695-0-0-0',
#   '5-0-0-0-0',
#   '9-137-0-0-0',
#   '38-250-0-0-0',
#   '12-25-71-0-0',
#   '38-0-0-0-0',
#   '10-362-0-0-0',
#   '15-42-0-0-0',
#   '17-33-0-0-0',
#   '2-171-0-0-0',
#   '2-46-1060-0-0',
#   '9-0-0-0-0',
#   '14-11-0-0-0',
#   '13-311-0-0-0',
#   '12-45-53-90-0',
#   '4-906-0-0-0',
#   '12-88-0-0-0',
#   '2-46-0-0-0',
#   '2-86-0-0-0',
#   '3-567-0-0-0',
#   '15-297-240-0-0',
#   '12-36-0-0-0',
#   '4-74-0-0-0',
#   '1235-18-0-0-0',
#   '38-224-0-0-0',
#   '15-236-0-0-0',
#   '12-85-404-0-0',
#   '2-77-0-0-0',
#   '4-97-0-0-0',
#   '2-92-81-0-0',
#   '2-79-0-0-0',
#   '15-468-0-0-0',
#   '2-86-174-0-0',
#   '5-187-0-0-0',
#   '38-32-0-0-0',
#   '12-25-111-0-0',
#   '21-539-0-0-0',
#   '21-811-0-0-0',
#   '15-286-0-0-0',
#   '17-0-0-0-0',
#   '12-25-0-0-0',
#   '12-98-0-0-0',
#   '8-0-0-0-0',
#   '12-27-0-0-0',
#   '38-125-0-0-0',
#   '2-46-502-0-0',
#   '20-65-166-0-0',
#   '5-659-0-0-0',
#   '15-495-0-0-0',
#   '17-49-0-0-0',
#   '2-0-0-0-0',
#   '21-542-0-0-0',
#   '12-31-167-0-0',
#   '2-232-0-0-0',
#   '38-186-0-0-0',
#   '10-76-0-0-0',
#   '12-31-0-0-0',
#   '12-26-0-0-0',
#   '5-322-0-0-0',
#   '20-138-0-0-0',
#   '2-130-1156-0-0',
#   '21-580-0-0-0',
#   '21-100-0-0-0',
#   '12-58-0-0-0',
#   '21-0-0-0-0',
#   '12-26-113-0-0',
#   '12-25-109-0-0',
#   '38-6-360-0-0',
#   '9-651-0-0-0',
#   '2-130-741-0-0',
#   '38-22-0-0-0',
#   '13-170-0-0-0',
#   '20-378-0-0-0',
#   '4-179-0-0-0',
#   '15-184-0-0-0',
#   '2-172-0-0-0',
#   '38-1-0-0-0',
#   '1235-0-0-0-0',
#   '17-180-0-0-0',
#   '2-130-0-0-0',
#   '12-25-109-361-0',
#   '20-65-43-0-0',
#   '38-456-0-0-0',
#   '12-45-53-0-0',
#   '2-504-0-0-0',
#   '12-85-0-0-0',
#   '21-693-0-0-0',
#   '12-45-0-0-0',
#   '4-0-0-0-0',
#   '2-79-602-0-0',
#   '2-176-0-0-0',
#   '20-65-0-0-0',
#   '1235-18-538-0-0',
#   '20-0-0-0-0',
#   '1235-107-0-0-0',
#   '15-183-0-0-0',
#   '2-102-1032-0-0',
#   '9-63-0-0-0',
#   '14-19-0-0-0',
#   '5-444-0-0-0',
#   '38-247-0-0-0',
#   '9-169-0-0-0',
#   '13-0-0-0-0',
#   '15-181-401-0-0',
#   '12-25-89-0-0',
#   '38-6-16-763-0',
#   '15-0-0-0-0',
#   '38-47-0-0-0',
#   '12-440-0-0-0',
#   '12-31-439-0-0',
#   '15-297-0-0-0',
#   '17-103-0-0-0',
#   '15-296-0-0-0',
#   '2-177-0-0-0',
#   '1235-267-0-0-0',
#   '10-0-0-0-0',
#   '2-92-214-0-0',
#   '38-30-0-0-0',
#   '20-188-0-0-0',
#   '17-94-0-0-0',
#   '3-0-0-0-0',
#   '4-37-0-0-0',
#   '2-130-619-0-0',
#   '21-83-0-0-0',
#   '15-337-0-0-0',
#   '5-441-0-0-0',
#   '12-31-101-0-0',
#   '14-0-0-0-0'],
#  'label1_name': {'15': 'Electronic',
#   '4': 'Jazz',
#   '12': 'Rock',
#   '10': 'Pop',
#   '17': 'Folk',
#   '2': 'International',
#   '38': 'Experimental',
#   '5': 'Classical',
#   '1235': 'Instrumental',
#   '21': 'Hip-Hop',
#   '9': 'Country',
#   '20': 'Spoken',
#   '3': 'Blues',
#   '13': 'Easy Listening',
#   '14': 'Soul-RnB',
#   '8': 'Old-Time / Historic'},
#  'label2_name': {'15-468': 'Electronic>Dubstep',
#   '4-74': 'Jazz>Free-Jazz',
#   '12-25': 'Rock>Punk',
#   '12-58': 'Rock>Psych-Rock',
#   '10-362': 'Pop>Synth Pop',
#   '17-103': 'Folk>Singer-Songwriter',
#   '2-118': 'International>Balkan',
#   '12-45': 'Rock>Loud-Rock',
#   '12-27': 'Rock>Lo-Fi',
#   '38-247': 'Experimental>Musique Concrete',
#   '12-85': 'Rock>Garage',
#   '12-66': 'Rock>Indie-Rock',
#   '38-224': 'Experimental>Sound Collage',
#   '15-337': 'Electronic>Drum & Bass',
#   '38-250': 'Experimental>Improv',
#   '12-98': 'Rock>Progressive',
#   '15-297': 'Electronic>Chip Music',
#   '15-286': 'Electronic>Trip-Hop',
#   '5-322': 'Classical>Composed Music',
#   '1235-0': 'Instrumental>Instrumental',
#   '38-0': 'Experimental>Experimental',
#   '5-659': 'Classical>Contemporary Classical',
#   '21-0': 'Hip-Hop>Hip-Hop',
#   '15-182': 'Electronic>House',
#   '4-0': 'Jazz>Jazz',
#   '38-514': 'Experimental>Sound Art',
#   '5-0': 'Classical>Classical',
#   '5-187': 'Classical>20th Century Classical',
#   '15-236': 'Electronic>IDM',
#   '38-32': 'Experimental>Noise',
#   '9-0': 'Country>Country',
#   '10-76': 'Pop>Experimental Pop',
#   '4-97': 'Jazz>Jazz: Out',
#   '12-26': 'Rock>Post-Rock',
#   '15-42': 'Electronic>Ambient Electronic',
#   '38-456': 'Experimental>Minimalism',
#   '38-41': 'Experimental>Electroacoustic',
#   '38-47': 'Experimental>Drone',
#   '20-138': 'Spoken>Spoken Weird',
#   '12-0': 'Rock>Rock',
#   '17-94': 'Folk>Freak-Folk',
#   '4-179': 'Jazz>Big Band/Swing',
#   '9-63': 'Country>Bluegrass',
#   '15-0': 'Electronic>Electronic',
#   '10-0': 'Pop>Pop',
#   '3-0': 'Blues>Blues',
#   '20-378': 'Spoken>Spoken Word',
#   '1235-18': 'Instrumental>Soundtrack',
#   '15-296': 'Electronic>Dance',
#   '1235-267': 'Instrumental>New Age',
#   '38-125': 'Experimental>Unclassifiable',
#   '1235-107': 'Instrumental>Ambient',
#   '2-46': 'International>Latin America',
#   '15-495': 'Electronic>Downtempo',
#   '38-22': 'Experimental>Audio Collage',
#   '21-811': 'Hip-Hop>Hip-Hop Beats',
#   '12-359': 'Rock>Shoegaze',
#   '17-0': 'Folk>Folk',
#   '2-86': 'International>Indian',
#   '20-65': 'Spoken>Radio',
#   '13-311': 'Easy Listening>Lounge',
#   '15-185': 'Electronic>Breakcore - Hard',
#   '12-70': 'Rock>Industrial',
#   '38-6': 'Experimental>Novelty',
#   '15-181': 'Electronic>Techno',
#   '12-31': 'Rock>Metal',
#   '2-171': 'International>Brazilian',
#   '38-30': 'Experimental>Field Recordings',
#   '20-188': 'Spoken>Poetry',
#   '21-100': 'Hip-Hop>Alternative Hip-Hop',
#   '14-19': 'Soul-RnB>Funk',
#   '38-186': 'Experimental>Sound Poetry',
#   '9-137': 'Country>Americana',
#   '15-183': 'Electronic>Glitch',
#   '12-314': 'Rock>Goth',
#   '5-443': 'Classical>Choral Music',
#   '17-49': 'Folk>Free-Folk',
#   '8-0': 'Old-Time / Historic>Old-Time / Historic',
#   '2-0': 'International>International',
#   '21-539': 'Hip-Hop>Rap',
#   '15-184': 'Electronic>Minimal Electronic',
#   '2-130': 'International>Europe',
#   '38-1': 'Experimental>Avant-Garde',
#   '15-695': 'Electronic>Jungle',
#   '2-77': 'International>French',
#   '21-83': 'Hip-Hop>Nerdcore',
#   '5-441': 'Classical>Opera',
#   '21-542': 'Hip-Hop>Breakbeat',
#   '2-79': 'International>Reggae - Dub',
#   '17-180': 'Folk>British Folk',
#   '13-0': 'Easy Listening>Easy Listening',
#   '4-37': 'Jazz>Jazz: Vocal',
#   '13-810': 'Easy Listening>Nu-Jazz',
#   '12-88': 'Rock>New Wave',
#   '17-33': 'Folk>Psych-Folk',
#   '3-567': 'Blues>Gospel',
#   '2-92': 'International>African',
#   '2-172': 'International>Asia-Far East',
#   '5-442': 'Classical>Chamber Music',
#   '2-177': 'International>Celtic',
#   '12-36': 'Rock>Krautrock',
#   '21-580': 'Hip-Hop>Abstract Hip-Hop',
#   '20-374': 'Spoken>Banter',
#   '2-176': 'International>Pacific',
#   '14-11': 'Soul-RnB>Disco',
#   '9-651': 'Country>Country & Western',
#   '4-906': 'Jazz>Modern Jazz',
#   '20-0': 'Spoken>Spoken',
#   '12-440': 'Rock>Rock Opera',
#   '14-0': 'Soul-RnB>Soul-RnB',
#   '21-693': 'Hip-Hop>Wonky',
#   '2-102': 'International>Middle East',
#   '13-170': 'Easy Listening>Easy Listening: Vocal',
#   '2-504': 'International>Latin',
#   '9-169': 'Country>Rockabilly',
#   '20-428': 'Spoken>Radio Theater',
#   '5-444': 'Classical>Symphony',
#   '2-232': 'International>Flamenco',
#   '2-117': 'International>Polka'},
#  'label3_name': {'15-468-0': 'Electronic>Dubstep>Dubstep',
#   '4-74-0': 'Jazz>Free-Jazz>Free-Jazz',
#   '12-25-71': 'Rock>Punk>No Wave',
#   '12-58-0': 'Rock>Psych-Rock>Psych-Rock',
#   '12-25-109': 'Rock>Punk>Hardcore',
#   '10-362-0': 'Pop>Synth Pop>Synth Pop',
#   '17-103-0': 'Folk>Singer-Songwriter>Singer-Songwriter',
#   '2-118-0': 'International>Balkan>Balkan',
#   '12-45-53': 'Rock>Loud-Rock>Noise-Rock',
#   '12-27-0': 'Rock>Lo-Fi>Lo-Fi',
#   '38-247-0': 'Experimental>Musique Concrete>Musique Concrete',
#   '12-85-0': 'Rock>Garage>Garage',
#   '12-66-0': 'Rock>Indie-Rock>Indie-Rock',
#   '38-224-0': 'Experimental>Sound Collage>Sound Collage',
#   '15-337-0': 'Electronic>Drum & Bass>Drum & Bass',
#   '38-250-0': 'Experimental>Improv>Improv',
#   '12-98-0': 'Rock>Progressive>Progressive',
#   '15-297-240': 'Electronic>Chip Music>Chiptune',
#   '15-297-0': 'Electronic>Chip Music>Chip Music',
#   '15-286-0': 'Electronic>Trip-Hop>Trip-Hop',
#   '5-322-0': 'Classical>Composed Music>Composed Music',
#   '1235-0-0': 'Instrumental>Instrumental>Instrumental',
#   '38-0-0': 'Experimental>Experimental>Experimental',
#   '5-659-0': 'Classical>Contemporary Classical>Contemporary Classical',
#   '21-0-0': 'Hip-Hop>Hip-Hop>Hip-Hop',
#   '15-182-400': 'Electronic>House>Chill-out',
#   '4-0-0': 'Jazz>Jazz>Jazz',
#   '38-514-0': 'Experimental>Sound Art>Sound Art',
#   '5-0-0': 'Classical>Classical>Classical',
#   '5-187-0': 'Classical>20th Century Classical>20th Century Classical',
#   '15-236-0': 'Electronic>IDM>IDM',
#   '38-32-0': 'Experimental>Noise>Noise',
#   '9-0-0': 'Country>Country>Country',
#   '10-76-0': 'Pop>Experimental Pop>Experimental Pop',
#   '4-97-0': 'Jazz>Jazz: Out>Jazz: Out',
#   '12-26-0': 'Rock>Post-Rock>Post-Rock',
#   '15-42-0': 'Electronic>Ambient Electronic>Ambient Electronic',
#   '38-456-0': 'Experimental>Minimalism>Minimalism',
#   '12-85-404': 'Rock>Garage>Surf',
#   '38-41-0': 'Experimental>Electroacoustic>Electroacoustic',
#   '38-47-0': 'Experimental>Drone>Drone',
#   '20-138-0': 'Spoken>Spoken Weird>Spoken Weird',
#   '12-0-0': 'Rock>Rock>Rock',
#   '17-94-0': 'Folk>Freak-Folk>Freak-Folk',
#   '12-25-0': 'Rock>Punk>Punk',
#   '4-179-0': 'Jazz>Big Band/Swing>Big Band/Swing',
#   '9-63-0': 'Country>Bluegrass>Bluegrass',
#   '15-0-0': 'Electronic>Electronic>Electronic',
#   '10-0-0': 'Pop>Pop>Pop',
#   '3-0-0': 'Blues>Blues>Blues',
#   '20-378-0': 'Spoken>Spoken Word>Spoken Word',
#   '1235-18-538': 'Instrumental>Soundtrack>Compilation',
#   '15-296-0': 'Electronic>Dance>Dance',
#   '12-25-89': 'Rock>Punk>Post-Punk',
#   '1235-267-0': 'Instrumental>New Age>New Age',
#   '38-125-0': 'Experimental>Unclassifiable>Unclassifiable',
#   '1235-107-0': 'Instrumental>Ambient>Ambient',
#   '2-46-0': 'International>Latin America>Latin America',
#   '15-495-0': 'Electronic>Downtempo>Downtempo',
#   '38-22-0': 'Experimental>Audio Collage>Audio Collage',
#   '21-811-0': 'Hip-Hop>Hip-Hop Beats>Hip-Hop Beats',
#   '1235-18-0': 'Instrumental>Soundtrack>Soundtrack',
#   '12-359-0': 'Rock>Shoegaze>Shoegaze',
#   '17-0-0': 'Folk>Folk>Folk',
#   '2-86-0': 'International>Indian>Indian',
#   '12-25-111': 'Rock>Punk>Power-Pop',
#   '20-65-0': 'Spoken>Radio>Radio',
#   '13-311-0': 'Easy Listening>Lounge>Lounge',
#   '15-185-0': 'Electronic>Breakcore - Hard>Breakcore - Hard',
#   '12-70-0': 'Rock>Industrial>Industrial',
#   '12-45-0': 'Rock>Loud-Rock>Loud-Rock',
#   '38-6-16': 'Experimental>Novelty>Sound Effects',
#   '15-181-401': 'Electronic>Techno>Bigbeat',
#   '15-181-0': 'Electronic>Techno>Techno',
#   '12-31-167': 'Rock>Metal>Black-Metal',
#   '2-171-0': 'International>Brazilian>Brazilian',
#   '15-182-0': 'Electronic>House>House',
#   '38-30-0': 'Experimental>Field Recordings>Field Recordings',
#   '20-188-0': 'Spoken>Poetry>Poetry',
#   '21-100-0': 'Hip-Hop>Alternative Hip-Hop>Alternative Hip-Hop',
#   '14-19-0': 'Soul-RnB>Funk>Funk',
#   '38-186-0': 'Experimental>Sound Poetry>Sound Poetry',
#   '9-137-0': 'Country>Americana>Americana',
#   '15-183-0': 'Electronic>Glitch>Glitch',
#   '12-314-0': 'Rock>Goth>Goth',
#   '5-443-0': 'Classical>Choral Music>Choral Music',
#   '17-49-0': 'Folk>Free-Folk>Free-Folk',
#   '8-0-0': 'Old-Time / Historic>Old-Time / Historic>Old-Time / Historic',
#   '2-0-0': 'International>International>International',
#   '21-539-0': 'Hip-Hop>Rap>Rap',
#   '15-184-0': 'Electronic>Minimal Electronic>Minimal Electronic',
#   '2-130-741': 'International>Europe>Klezmer',
#   '38-1-0': 'Experimental>Avant-Garde>Avant-Garde',
#   '15-695-0': 'Electronic>Jungle>Jungle',
#   '2-77-0': 'International>French>French',
#   '21-83-0': 'Hip-Hop>Nerdcore>Nerdcore',
#   '5-441-0': 'Classical>Opera>Opera',
#   '38-6-360': 'Experimental>Novelty>Kid-Friendly',
#   '21-542-0': 'Hip-Hop>Breakbeat>Breakbeat',
#   '2-79-0': 'International>Reggae - Dub>Reggae - Dub',
#   '12-25-64': 'Rock>Punk>Electro-Punk',
#   '12-31-0': 'Rock>Metal>Metal',
#   '17-180-0': 'Folk>British Folk>British Folk',
#   '13-0-0': 'Easy Listening>Easy Listening>Easy Listening',
#   '12-31-439': 'Rock>Metal>Grindcore',
#   '4-37-0': 'Jazz>Jazz: Vocal>Jazz: Vocal',
#   '15-468-491': 'Electronic>Dubstep>Skweee',
#   '13-810-0': 'Easy Listening>Nu-Jazz>Nu-Jazz',
#   '12-88-0': 'Rock>New Wave>New Wave',
#   '2-130-0': 'International>Europe>Europe',
#   '17-33-0': 'Folk>Psych-Folk>Psych-Folk',
#   '3-567-0': 'Blues>Gospel>Gospel',
#   '12-26-113': 'Rock>Post-Rock>Space-Rock',
#   '2-79-602': 'International>Reggae - Dub>Reggae - Dancehall',
#   '2-92-0': 'International>African>African',
#   '2-172-0': 'International>Asia-Far East>Asia-Far East',
#   '20-65-166': 'Spoken>Radio>Interview',
#   '12-31-101': 'Rock>Metal>Death-Metal',
#   '5-442-0': 'Classical>Chamber Music>Chamber Music',
#   '2-86-174': 'International>Indian>South Indian Traditional',
#   '2-130-524': 'International>Europe>Romany (Gypsy)',
#   '2-177-0': 'International>Celtic>Celtic',
#   '12-36-0': 'Rock>Krautrock>Krautrock',
#   '2-46-808': 'International>Latin America>Salsa',
#   '21-580-0': 'Hip-Hop>Abstract Hip-Hop>Abstract Hip-Hop',
#   '20-374-0': 'Spoken>Banter>Banter',
#   '2-176-0': 'International>Pacific>Pacific',
#   '14-11-0': 'Soul-RnB>Disco>Disco',
#   '9-651-0': 'Country>Country & Western>Country & Western',
#   '2-46-1060': 'International>Latin America>Tango',
#   '4-906-0': 'Jazz>Modern Jazz>Modern Jazz',
#   '20-0-0': 'Spoken>Spoken>Spoken',
#   '12-440-0': 'Rock>Rock Opera>Rock Opera',
#   '14-0-0': 'Soul-RnB>Soul-RnB>Soul-RnB',
#   '21-693-0': 'Hip-Hop>Wonky>Wonky',
#   '2-102-1032': 'International>Middle East>Turkish',
#   '13-170-0': 'Easy Listening>Easy Listening: Vocal>Easy Listening: Vocal',
#   '2-504-0': 'International>Latin>Latin',
#   '2-130-619': 'International>Europe>Spanish',
#   '2-102-0': 'International>Middle East>Middle East',
#   '9-169-0': 'Country>Rockabilly>Rockabilly',
#   '2-130-1156': 'International>Europe>Fado',
#   '20-428-0': 'Spoken>Radio Theater>Radio Theater',
#   '38-6-0': 'Experimental>Novelty>Novelty',
#   '2-92-81': 'International>African>Afrobeat',
#   '5-444-0': 'Classical>Symphony>Symphony',
#   '2-92-214': 'International>African>North African',
#   '2-232-0': 'International>Flamenco>Flamenco',
#   '2-117-0': 'International>Polka>Polka',
#   '2-46-502': 'International>Latin America>Cumbia',
#   '20-65-43': 'Spoken>Radio>Radio Art'},
#  'label4_name': {'15-468-0-0': 'Electronic>Dubstep>Dubstep>Dubstep',
#   '4-74-0-0': 'Jazz>Free-Jazz>Free-Jazz>Free-Jazz',
#   '12-25-71-0': 'Rock>Punk>No Wave>No Wave',
#   '12-58-0-0': 'Rock>Psych-Rock>Psych-Rock>Psych-Rock',
#   '12-25-109-0': 'Rock>Punk>Hardcore>Hardcore',
#   '10-362-0-0': 'Pop>Synth Pop>Synth Pop>Synth Pop',
#   '17-103-0-0': 'Folk>Singer-Songwriter>Singer-Songwriter>Singer-Songwriter',
#   '2-118-0-0': 'International>Balkan>Balkan>Balkan',
#   '12-45-53-0': 'Rock>Loud-Rock>Noise-Rock>Noise-Rock',
#   '12-27-0-0': 'Rock>Lo-Fi>Lo-Fi>Lo-Fi',
#   '38-247-0-0': 'Experimental>Musique Concrete>Musique Concrete>Musique Concrete',
#   '12-85-0-0': 'Rock>Garage>Garage>Garage',
#   '12-66-0-0': 'Rock>Indie-Rock>Indie-Rock>Indie-Rock',
#   '38-224-0-0': 'Experimental>Sound Collage>Sound Collage>Sound Collage',
#   '15-337-0-0': 'Electronic>Drum & Bass>Drum & Bass>Drum & Bass',
#   '38-250-0-0': 'Experimental>Improv>Improv>Improv',
#   '12-98-0-0': 'Rock>Progressive>Progressive>Progressive',
#   '15-297-240-0': 'Electronic>Chip Music>Chiptune>Chiptune',
#   '15-297-0-0': 'Electronic>Chip Music>Chip Music>Chip Music',
#   '15-286-0-0': 'Electronic>Trip-Hop>Trip-Hop>Trip-Hop',
#   '5-322-0-0': 'Classical>Composed Music>Composed Music>Composed Music',
#   '1235-0-0-0': 'Instrumental>Instrumental>Instrumental>Instrumental',
#   '38-0-0-0': 'Experimental>Experimental>Experimental>Experimental',
#   '5-659-0-0': 'Classical>Contemporary Classical>Contemporary Classical>Contemporary Classical',
#   '21-0-0-0': 'Hip-Hop>Hip-Hop>Hip-Hop>Hip-Hop',
#   '15-182-400-0': 'Electronic>House>Chill-out>Chill-out',
#   '4-0-0-0': 'Jazz>Jazz>Jazz>Jazz',
#   '38-514-0-0': 'Experimental>Sound Art>Sound Art>Sound Art',
#   '5-0-0-0': 'Classical>Classical>Classical>Classical',
#   '5-187-0-0': 'Classical>20th Century Classical>20th Century Classical>20th Century Classical',
#   '15-236-0-0': 'Electronic>IDM>IDM>IDM',
#   '38-32-0-0': 'Experimental>Noise>Noise>Noise',
#   '9-0-0-0': 'Country>Country>Country>Country',
#   '10-76-0-0': 'Pop>Experimental Pop>Experimental Pop>Experimental Pop',
#   '4-97-0-0': 'Jazz>Jazz: Out>Jazz: Out>Jazz: Out',
#   '12-26-0-0': 'Rock>Post-Rock>Post-Rock>Post-Rock',
#   '15-42-0-0': 'Electronic>Ambient Electronic>Ambient Electronic>Ambient Electronic',
#   '38-456-0-0': 'Experimental>Minimalism>Minimalism>Minimalism',
#   '12-85-404-0': 'Rock>Garage>Surf>Surf',
#   '38-41-0-0': 'Experimental>Electroacoustic>Electroacoustic>Electroacoustic',
#   '38-47-0-0': 'Experimental>Drone>Drone>Drone',
#   '20-138-0-0': 'Spoken>Spoken Weird>Spoken Weird>Spoken Weird',
#   '12-0-0-0': 'Rock>Rock>Rock>Rock',
#   '17-94-0-0': 'Folk>Freak-Folk>Freak-Folk>Freak-Folk',
#   '12-25-0-0': 'Rock>Punk>Punk>Punk',
#   '4-179-0-0': 'Jazz>Big Band/Swing>Big Band/Swing>Big Band/Swing',
#   '9-63-0-0': 'Country>Bluegrass>Bluegrass>Bluegrass',
#   '15-0-0-0': 'Electronic>Electronic>Electronic>Electronic',
#   '10-0-0-0': 'Pop>Pop>Pop>Pop',
#   '3-0-0-0': 'Blues>Blues>Blues>Blues',
#   '20-378-0-0': 'Spoken>Spoken Word>Spoken Word>Spoken Word',
#   '1235-18-538-0': 'Instrumental>Soundtrack>Compilation>Compilation',
#   '15-296-0-0': 'Electronic>Dance>Dance>Dance',
#   '12-25-89-0': 'Rock>Punk>Post-Punk>Post-Punk',
#   '1235-267-0-0': 'Instrumental>New Age>New Age>New Age',
#   '38-125-0-0': 'Experimental>Unclassifiable>Unclassifiable>Unclassifiable',
#   '1235-107-0-0': 'Instrumental>Ambient>Ambient>Ambient',
#   '2-46-0-0': 'International>Latin America>Latin America>Latin America',
#   '15-495-0-0': 'Electronic>Downtempo>Downtempo>Downtempo',
#   '38-22-0-0': 'Experimental>Audio Collage>Audio Collage>Audio Collage',
#   '21-811-0-0': 'Hip-Hop>Hip-Hop Beats>Hip-Hop Beats>Hip-Hop Beats',
#   '1235-18-0-0': 'Instrumental>Soundtrack>Soundtrack>Soundtrack',
#   '12-45-53-90': 'Rock>Loud-Rock>Noise-Rock>Sludge',
#   '12-359-0-0': 'Rock>Shoegaze>Shoegaze>Shoegaze',
#   '17-0-0-0': 'Folk>Folk>Folk>Folk',
#   '2-86-0-0': 'International>Indian>Indian>Indian',
#   '12-25-111-0': 'Rock>Punk>Power-Pop>Power-Pop',
#   '20-65-0-0': 'Spoken>Radio>Radio>Radio',
#   '13-311-0-0': 'Easy Listening>Lounge>Lounge>Lounge',
#   '15-185-0-0': 'Electronic>Breakcore - Hard>Breakcore - Hard>Breakcore - Hard',
#   '12-70-0-0': 'Rock>Industrial>Industrial>Industrial',
#   '12-45-0-0': 'Rock>Loud-Rock>Loud-Rock>Loud-Rock',
#   '38-6-16-763': 'Experimental>Novelty>Sound Effects>Holiday',
#   '15-181-401-0': 'Electronic>Techno>Bigbeat>Bigbeat',
#   '15-181-0-0': 'Electronic>Techno>Techno>Techno',
#   '12-31-167-0': 'Rock>Metal>Black-Metal>Black-Metal',
#   '2-171-0-0': 'International>Brazilian>Brazilian>Brazilian',
#   '15-182-0-0': 'Electronic>House>House>House',
#   '38-30-0-0': 'Experimental>Field Recordings>Field Recordings>Field Recordings',
#   '20-188-0-0': 'Spoken>Poetry>Poetry>Poetry',
#   '21-100-0-0': 'Hip-Hop>Alternative Hip-Hop>Alternative Hip-Hop>Alternative Hip-Hop',
#   '14-19-0-0': 'Soul-RnB>Funk>Funk>Funk',
#   '38-186-0-0': 'Experimental>Sound Poetry>Sound Poetry>Sound Poetry',
#   '9-137-0-0': 'Country>Americana>Americana>Americana',
#   '15-183-0-0': 'Electronic>Glitch>Glitch>Glitch',
#   '12-314-0-0': 'Rock>Goth>Goth>Goth',
#   '5-443-0-0': 'Classical>Choral Music>Choral Music>Choral Music',
#   '17-49-0-0': 'Folk>Free-Folk>Free-Folk>Free-Folk',
#   '8-0-0-0': 'Old-Time / Historic>Old-Time / Historic>Old-Time / Historic>Old-Time / Historic',
#   '2-0-0-0': 'International>International>International>International',
#   '21-539-0-0': 'Hip-Hop>Rap>Rap>Rap',
#   '15-184-0-0': 'Electronic>Minimal Electronic>Minimal Electronic>Minimal Electronic',
#   '2-130-741-0': 'International>Europe>Klezmer>Klezmer',
#   '38-1-0-0': 'Experimental>Avant-Garde>Avant-Garde>Avant-Garde',
#   '15-695-0-0': 'Electronic>Jungle>Jungle>Jungle',
#   '2-77-0-0': 'International>French>French>French',
#   '21-83-0-0': 'Hip-Hop>Nerdcore>Nerdcore>Nerdcore',
#   '5-441-0-0': 'Classical>Opera>Opera>Opera',
#   '38-6-360-0': 'Experimental>Novelty>Kid-Friendly>Kid-Friendly',
#   '21-542-0-0': 'Hip-Hop>Breakbeat>Breakbeat>Breakbeat',
#   '2-79-0-0': 'International>Reggae - Dub>Reggae - Dub>Reggae - Dub',
#   '12-25-64-0': 'Rock>Punk>Electro-Punk>Electro-Punk',
#   '12-31-0-0': 'Rock>Metal>Metal>Metal',
#   '17-180-0-0': 'Folk>British Folk>British Folk>British Folk',
#   '13-0-0-0': 'Easy Listening>Easy Listening>Easy Listening>Easy Listening',
#   '12-31-439-0': 'Rock>Metal>Grindcore>Grindcore',
#   '4-37-0-0': 'Jazz>Jazz: Vocal>Jazz: Vocal>Jazz: Vocal',
#   '15-468-491-0': 'Electronic>Dubstep>Skweee>Skweee',
#   '13-810-0-0': 'Easy Listening>Nu-Jazz>Nu-Jazz>Nu-Jazz',
#   '12-88-0-0': 'Rock>New Wave>New Wave>New Wave',
#   '2-130-0-0': 'International>Europe>Europe>Europe',
#   '17-33-0-0': 'Folk>Psych-Folk>Psych-Folk>Psych-Folk',
#   '3-567-0-0': 'Blues>Gospel>Gospel>Gospel',
#   '12-26-113-0': 'Rock>Post-Rock>Space-Rock>Space-Rock',
#   '2-79-602-0': 'International>Reggae - Dub>Reggae - Dancehall>Reggae - Dancehall',
#   '2-92-0-0': 'International>African>African>African',
#   '2-172-0-0': 'International>Asia-Far East>Asia-Far East>Asia-Far East',
#   '20-65-166-0': 'Spoken>Radio>Interview>Interview',
#   '12-31-101-0': 'Rock>Metal>Death-Metal>Death-Metal',
#   '5-442-0-0': 'Classical>Chamber Music>Chamber Music>Chamber Music',
#   '2-86-174-0': 'International>Indian>South Indian Traditional>South Indian Traditional',
#   '2-130-524-0': 'International>Europe>Romany (Gypsy)>Romany (Gypsy)',
#   '2-177-0-0': 'International>Celtic>Celtic>Celtic',
#   '12-36-0-0': 'Rock>Krautrock>Krautrock>Krautrock',
#   '2-46-808-0': 'International>Latin America>Salsa>Salsa',
#   '21-580-0-0': 'Hip-Hop>Abstract Hip-Hop>Abstract Hip-Hop>Abstract Hip-Hop',
#   '20-374-0-0': 'Spoken>Banter>Banter>Banter',
#   '2-176-0-0': 'International>Pacific>Pacific>Pacific',
#   '12-25-109-361': 'Rock>Punk>Hardcore>Thrash',
#   '14-11-0-0': 'Soul-RnB>Disco>Disco>Disco',
#   '9-651-0-0': 'Country>Country & Western>Country & Western>Country & Western',
#   '2-46-1060-0': 'International>Latin America>Tango>Tango',
#   '4-906-0-0': 'Jazz>Modern Jazz>Modern Jazz>Modern Jazz',
#   '20-0-0-0': 'Spoken>Spoken>Spoken>Spoken',
#   '12-440-0-0': 'Rock>Rock Opera>Rock Opera>Rock Opera',
#   '14-0-0-0': 'Soul-RnB>Soul-RnB>Soul-RnB>Soul-RnB',
#   '21-693-0-0': 'Hip-Hop>Wonky>Wonky>Wonky',
#   '2-102-1032-0': 'International>Middle East>Turkish>Turkish',
#   '13-170-0-0': 'Easy Listening>Easy Listening: Vocal>Easy Listening: Vocal>Easy Listening: Vocal',
#   '2-504-0-0': 'International>Latin>Latin>Latin',
#   '2-130-619-0': 'International>Europe>Spanish>Spanish',
#   '2-102-0-0': 'International>Middle East>Middle East>Middle East',
#   '9-169-0-0': 'Country>Rockabilly>Rockabilly>Rockabilly',
#   '2-130-1156-0': 'International>Europe>Fado>Fado',
#   '20-428-0-0': 'Spoken>Radio Theater>Radio Theater>Radio Theater',
#   '38-6-0-0': 'Experimental>Novelty>Novelty>Novelty',
#   '2-92-81-0': 'International>African>Afrobeat>Afrobeat',
#   '5-444-0-0': 'Classical>Symphony>Symphony>Symphony',
#   '2-92-214-0': 'International>African>North African>North African',
#   '2-232-0-0': 'International>Flamenco>Flamenco>Flamenco',
#   '2-117-0-0': 'International>Polka>Polka>Polka',
#   '2-46-502-0': 'International>Latin America>Cumbia>Cumbia',
#   '20-65-43-0': 'Spoken>Radio>Radio Art>Radio Art'},
#  'label5_name': {'15-468-0-0-0': 'Electronic>Dubstep>Dubstep>Dubstep>Dubstep',
#   '4-74-0-0-0': 'Jazz>Free-Jazz>Free-Jazz>Free-Jazz>Free-Jazz',
#   '12-25-71-0-0': 'Rock>Punk>No Wave>No Wave>No Wave',
#   '12-58-0-0-0': 'Rock>Psych-Rock>Psych-Rock>Psych-Rock>Psych-Rock',
#   '12-25-109-0-0': 'Rock>Punk>Hardcore>Hardcore>Hardcore',
#   '10-362-0-0-0': 'Pop>Synth Pop>Synth Pop>Synth Pop>Synth Pop',
#   '17-103-0-0-0': 'Folk>Singer-Songwriter>Singer-Songwriter>Singer-Songwriter>Singer-Songwriter',
#   '2-118-0-0-0': 'International>Balkan>Balkan>Balkan>Balkan',
#   '12-45-53-0-0': 'Rock>Loud-Rock>Noise-Rock>Noise-Rock>Noise-Rock',
#   '12-27-0-0-0': 'Rock>Lo-Fi>Lo-Fi>Lo-Fi>Lo-Fi',
#   '38-247-0-0-0': 'Experimental>Musique Concrete>Musique Concrete>Musique Concrete>Musique Concrete',
#   '12-85-0-0-0': 'Rock>Garage>Garage>Garage>Garage',
#   '12-66-0-0-0': 'Rock>Indie-Rock>Indie-Rock>Indie-Rock>Indie-Rock',
#   '38-224-0-0-0': 'Experimental>Sound Collage>Sound Collage>Sound Collage>Sound Collage',
#   '15-337-0-0-0': 'Electronic>Drum & Bass>Drum & Bass>Drum & Bass>Drum & Bass',
#   '38-250-0-0-0': 'Experimental>Improv>Improv>Improv>Improv',
#   '12-98-0-0-0': 'Rock>Progressive>Progressive>Progressive>Progressive',
#   '15-297-240-0-0': 'Electronic>Chip Music>Chiptune>Chiptune>Chiptune',
#   '15-297-0-0-0': 'Electronic>Chip Music>Chip Music>Chip Music>Chip Music',
#   '15-286-0-0-0': 'Electronic>Trip-Hop>Trip-Hop>Trip-Hop>Trip-Hop',
#   '5-322-0-0-0': 'Classical>Composed Music>Composed Music>Composed Music>Composed Music',
#   '1235-0-0-0-0': 'Instrumental>Instrumental>Instrumental>Instrumental>Instrumental',
#   '38-0-0-0-0': 'Experimental>Experimental>Experimental>Experimental>Experimental',
#   '5-659-0-0-0': 'Classical>Contemporary Classical>Contemporary Classical>Contemporary Classical>Contemporary Classical',
#   '21-0-0-0-0': 'Hip-Hop>Hip-Hop>Hip-Hop>Hip-Hop>Hip-Hop',
#   '15-182-400-0-0': 'Electronic>House>Chill-out>Chill-out>Chill-out',
#   '4-0-0-0-0': 'Jazz>Jazz>Jazz>Jazz>Jazz',
#   '38-514-0-0-0': 'Experimental>Sound Art>Sound Art>Sound Art>Sound Art',
#   '5-0-0-0-0': 'Classical>Classical>Classical>Classical>Classical',
#   '5-187-0-0-0': 'Classical>20th Century Classical>20th Century Classical>20th Century Classical>20th Century Classical',
#   '15-236-0-0-0': 'Electronic>IDM>IDM>IDM>IDM',
#   '38-32-0-0-0': 'Experimental>Noise>Noise>Noise>Noise',
#   '9-0-0-0-0': 'Country>Country>Country>Country>Country',
#   '10-76-0-0-0': 'Pop>Experimental Pop>Experimental Pop>Experimental Pop>Experimental Pop',
#   '4-97-0-0-0': 'Jazz>Jazz: Out>Jazz: Out>Jazz: Out>Jazz: Out',
#   '12-26-0-0-0': 'Rock>Post-Rock>Post-Rock>Post-Rock>Post-Rock',
#   '15-42-0-0-0': 'Electronic>Ambient Electronic>Ambient Electronic>Ambient Electronic>Ambient Electronic',
#   '38-456-0-0-0': 'Experimental>Minimalism>Minimalism>Minimalism>Minimalism',
#   '12-85-404-0-0': 'Rock>Garage>Surf>Surf>Surf',
#   '38-41-0-0-0': 'Experimental>Electroacoustic>Electroacoustic>Electroacoustic>Electroacoustic',
#   '38-47-0-0-0': 'Experimental>Drone>Drone>Drone>Drone',
#   '20-138-0-0-0': 'Spoken>Spoken Weird>Spoken Weird>Spoken Weird>Spoken Weird',
#   '12-0-0-0-0': 'Rock>Rock>Rock>Rock>Rock',
#   '17-94-0-0-0': 'Folk>Freak-Folk>Freak-Folk>Freak-Folk>Freak-Folk',
#   '12-25-0-0-0': 'Rock>Punk>Punk>Punk>Punk',
#   '4-179-0-0-0': 'Jazz>Big Band/Swing>Big Band/Swing>Big Band/Swing>Big Band/Swing',
#   '9-63-0-0-0': 'Country>Bluegrass>Bluegrass>Bluegrass>Bluegrass',
#   '15-0-0-0-0': 'Electronic>Electronic>Electronic>Electronic>Electronic',
#   '10-0-0-0-0': 'Pop>Pop>Pop>Pop>Pop',
#   '3-0-0-0-0': 'Blues>Blues>Blues>Blues>Blues',
#   '20-378-0-0-0': 'Spoken>Spoken Word>Spoken Word>Spoken Word>Spoken Word',
#   '1235-18-538-0-0': 'Instrumental>Soundtrack>Compilation>Compilation>Compilation',
#   '15-296-0-0-0': 'Electronic>Dance>Dance>Dance>Dance',
#   '12-25-89-0-0': 'Rock>Punk>Post-Punk>Post-Punk>Post-Punk',
#   '1235-267-0-0-0': 'Instrumental>New Age>New Age>New Age>New Age',
#   '38-125-0-0-0': 'Experimental>Unclassifiable>Unclassifiable>Unclassifiable>Unclassifiable',
#   '1235-107-0-0-0': 'Instrumental>Ambient>Ambient>Ambient>Ambient',
#   '2-46-0-0-0': 'International>Latin America>Latin America>Latin America>Latin America',
#   '15-495-0-0-0': 'Electronic>Downtempo>Downtempo>Downtempo>Downtempo',
#   '38-22-0-0-0': 'Experimental>Audio Collage>Audio Collage>Audio Collage>Audio Collage',
#   '21-811-0-0-0': 'Hip-Hop>Hip-Hop Beats>Hip-Hop Beats>Hip-Hop Beats>Hip-Hop Beats',
#   '1235-18-0-0-0': 'Instrumental>Soundtrack>Soundtrack>Soundtrack>Soundtrack',
#   '12-45-53-90-0': 'Rock>Loud-Rock>Noise-Rock>Sludge>Sludge',
#   '12-359-0-0-0': 'Rock>Shoegaze>Shoegaze>Shoegaze>Shoegaze',
#   '17-0-0-0-0': 'Folk>Folk>Folk>Folk>Folk',
#   '2-86-0-0-0': 'International>Indian>Indian>Indian>Indian',
#   '12-25-111-0-0': 'Rock>Punk>Power-Pop>Power-Pop>Power-Pop',
#   '20-65-0-0-0': 'Spoken>Radio>Radio>Radio>Radio',
#   '13-311-0-0-0': 'Easy Listening>Lounge>Lounge>Lounge>Lounge',
#   '15-185-0-0-0': 'Electronic>Breakcore - Hard>Breakcore - Hard>Breakcore - Hard>Breakcore - Hard',
#   '12-70-0-0-0': 'Rock>Industrial>Industrial>Industrial>Industrial',
#   '12-45-0-0-0': 'Rock>Loud-Rock>Loud-Rock>Loud-Rock>Loud-Rock',
#   '38-6-16-763-0': 'Experimental>Novelty>Sound Effects>Holiday>Holiday',
#   '15-181-401-0-0': 'Electronic>Techno>Bigbeat>Bigbeat>Bigbeat',
#   '15-181-0-0-0': 'Electronic>Techno>Techno>Techno>Techno',
#   '12-31-167-0-0': 'Rock>Metal>Black-Metal>Black-Metal>Black-Metal',
#   '2-171-0-0-0': 'International>Brazilian>Brazilian>Brazilian>Brazilian',
#   '15-182-0-0-0': 'Electronic>House>House>House>House',
#   '38-30-0-0-0': 'Experimental>Field Recordings>Field Recordings>Field Recordings>Field Recordings',
#   '20-188-0-0-0': 'Spoken>Poetry>Poetry>Poetry>Poetry',
#   '21-100-0-0-0': 'Hip-Hop>Alternative Hip-Hop>Alternative Hip-Hop>Alternative Hip-Hop>Alternative Hip-Hop',
#   '14-19-0-0-0': 'Soul-RnB>Funk>Funk>Funk>Funk',
#   '38-186-0-0-0': 'Experimental>Sound Poetry>Sound Poetry>Sound Poetry>Sound Poetry',
#   '9-137-0-0-0': 'Country>Americana>Americana>Americana>Americana',
#   '15-183-0-0-0': 'Electronic>Glitch>Glitch>Glitch>Glitch',
#   '12-314-0-0-0': 'Rock>Goth>Goth>Goth>Goth',
#   '5-443-0-0-0': 'Classical>Choral Music>Choral Music>Choral Music>Choral Music',
#   '17-49-0-0-0': 'Folk>Free-Folk>Free-Folk>Free-Folk>Free-Folk',
#   '8-0-0-0-0': 'Old-Time / Historic>Old-Time / Historic>Old-Time / Historic>Old-Time / Historic>Old-Time / Historic',
#   '2-0-0-0-0': 'International>International>International>International>International',
#   '21-539-0-0-0': 'Hip-Hop>Rap>Rap>Rap>Rap',
#   '15-184-0-0-0': 'Electronic>Minimal Electronic>Minimal Electronic>Minimal Electronic>Minimal Electronic',
#   '2-130-741-0-0': 'International>Europe>Klezmer>Klezmer>Klezmer',
#   '38-1-0-0-0': 'Experimental>Avant-Garde>Avant-Garde>Avant-Garde>Avant-Garde',
#   '15-695-0-0-0': 'Electronic>Jungle>Jungle>Jungle>Jungle',
#   '2-77-0-0-0': 'International>French>French>French>French',
#   '21-83-0-0-0': 'Hip-Hop>Nerdcore>Nerdcore>Nerdcore>Nerdcore',
#   '5-441-0-0-0': 'Classical>Opera>Opera>Opera>Opera',
#   '38-6-360-0-0': 'Experimental>Novelty>Kid-Friendly>Kid-Friendly>Kid-Friendly',
#   '21-542-0-0-0': 'Hip-Hop>Breakbeat>Breakbeat>Breakbeat>Breakbeat',
#   '2-79-0-0-0': 'International>Reggae - Dub>Reggae - Dub>Reggae - Dub>Reggae - Dub',
#   '12-25-64-0-0': 'Rock>Punk>Electro-Punk>Electro-Punk>Electro-Punk',
#   '12-31-0-0-0': 'Rock>Metal>Metal>Metal>Metal',
#   '17-180-0-0-0': 'Folk>British Folk>British Folk>British Folk>British Folk',
#   '13-0-0-0-0': 'Easy Listening>Easy Listening>Easy Listening>Easy Listening>Easy Listening',
#   '12-31-439-0-0': 'Rock>Metal>Grindcore>Grindcore>Grindcore',
#   '4-37-0-0-0': 'Jazz>Jazz: Vocal>Jazz: Vocal>Jazz: Vocal>Jazz: Vocal',
#   '15-468-491-0-0': 'Electronic>Dubstep>Skweee>Skweee>Skweee',
#   '13-810-0-0-0': 'Easy Listening>Nu-Jazz>Nu-Jazz>Nu-Jazz>Nu-Jazz',
#   '12-88-0-0-0': 'Rock>New Wave>New Wave>New Wave>New Wave',
#   '2-130-0-0-0': 'International>Europe>Europe>Europe>Europe',
#   '17-33-0-0-0': 'Folk>Psych-Folk>Psych-Folk>Psych-Folk>Psych-Folk',
#   '3-567-0-0-0': 'Blues>Gospel>Gospel>Gospel>Gospel',
#   '12-26-113-0-0': 'Rock>Post-Rock>Space-Rock>Space-Rock>Space-Rock',
#   '2-79-602-0-0': 'International>Reggae - Dub>Reggae - Dancehall>Reggae - Dancehall>Reggae - Dancehall',
#   '2-92-0-0-0': 'International>African>African>African>African',
#   '2-172-0-0-0': 'International>Asia-Far East>Asia-Far East>Asia-Far East>Asia-Far East',
#   '20-65-166-0-0': 'Spoken>Radio>Interview>Interview>Interview',
#   '12-31-101-0-0': 'Rock>Metal>Death-Metal>Death-Metal>Death-Metal',
#   '5-442-0-0-0': 'Classical>Chamber Music>Chamber Music>Chamber Music>Chamber Music',
#   '2-86-174-0-0': 'International>Indian>South Indian Traditional>South Indian Traditional>South Indian Traditional',
#   '2-130-524-0-0': 'International>Europe>Romany (Gypsy)>Romany (Gypsy)>Romany (Gypsy)',
#   '2-177-0-0-0': 'International>Celtic>Celtic>Celtic>Celtic',
#   '12-36-0-0-0': 'Rock>Krautrock>Krautrock>Krautrock>Krautrock',
#   '2-46-808-0-0': 'International>Latin America>Salsa>Salsa>Salsa',
#   '21-580-0-0-0': 'Hip-Hop>Abstract Hip-Hop>Abstract Hip-Hop>Abstract Hip-Hop>Abstract Hip-Hop',
#   '20-374-0-0-0': 'Spoken>Banter>Banter>Banter>Banter',
#   '2-176-0-0-0': 'International>Pacific>Pacific>Pacific>Pacific',
#   '12-25-109-361-0': 'Rock>Punk>Hardcore>Thrash>Thrash',
#   '14-11-0-0-0': 'Soul-RnB>Disco>Disco>Disco>Disco',
#   '9-651-0-0-0': 'Country>Country & Western>Country & Western>Country & Western>Country & Western',
#   '2-46-1060-0-0': 'International>Latin America>Tango>Tango>Tango',
#   '4-906-0-0-0': 'Jazz>Modern Jazz>Modern Jazz>Modern Jazz>Modern Jazz',
#   '20-0-0-0-0': 'Spoken>Spoken>Spoken>Spoken>Spoken',
#   '12-440-0-0-0': 'Rock>Rock Opera>Rock Opera>Rock Opera>Rock Opera',
#   '14-0-0-0-0': 'Soul-RnB>Soul-RnB>Soul-RnB>Soul-RnB>Soul-RnB',
#   '21-693-0-0-0': 'Hip-Hop>Wonky>Wonky>Wonky>Wonky',
#   '38-6-16-763-1193': 'Experimental>Novelty>Sound Effects>Holiday>Christmas',
#   '2-102-1032-0-0': 'International>Middle East>Turkish>Turkish>Turkish',
#   '13-170-0-0-0': 'Easy Listening>Easy Listening: Vocal>Easy Listening: Vocal>Easy Listening: Vocal>Easy Listening: Vocal',
#   '2-504-0-0-0': 'International>Latin>Latin>Latin>Latin',
#   '2-130-619-0-0': 'International>Europe>Spanish>Spanish>Spanish',
#   '2-102-0-0-0': 'International>Middle East>Middle East>Middle East>Middle East',
#   '9-169-0-0-0': 'Country>Rockabilly>Rockabilly>Rockabilly>Rockabilly',
#   '2-130-1156-0-0': 'International>Europe>Fado>Fado>Fado',
#   '20-428-0-0-0': 'Spoken>Radio Theater>Radio Theater>Radio Theater>Radio Theater',
#   '38-6-0-0-0': 'Experimental>Novelty>Novelty>Novelty>Novelty',
#   '2-92-81-0-0': 'International>African>Afrobeat>Afrobeat>Afrobeat',
#   '5-444-0-0-0': 'Classical>Symphony>Symphony>Symphony>Symphony',
#   '2-92-214-0-0': 'International>African>North African>North African>North African',
#   '2-232-0-0-0': 'International>Flamenco>Flamenco>Flamenco>Flamenco',
#   '2-117-0-0-0': 'International>Polka>Polka>Polka>Polka',
#   '2-46-502-0-0': 'International>Latin America>Cumbia>Cumbia>Cumbia',
#   '20-65-43-0-0': 'Spoken>Radio>Radio Art>Radio Art>Radio Art'},
#  'label1_count': 16,
#  'label2_count': 119,
#  'label3_count': 151,
#  'label4_count': 153,
#  'label5_count': 154}

# %%
tracks_df.labels_1.unique()
# Out:
# array([  15,    4,   12,   10,   17,    2,   38,    5, 1235,   21,    9,
#          20,    3,   13,   14,    8])

# %%
tqdm.pandas()

# %%
tracks_df['labels_1'] = tracks_df.labels_1.astype(str).progress_apply(lambda x: labels['label1'][x])

tracks_df['labels_2'] = tracks_df.labels_2.astype(str).progress_apply(lambda x: labels['label2'][x])

tracks_df['labels_3'] = tracks_df.labels_3.astype(str).progress_apply(lambda x: labels['label3'][x])

tracks_df['labels_4'] = tracks_df.labels_4.astype(str).progress_apply(lambda x: labels['label4'][x])

tracks_df['labels_5'] = tracks_df.labels_5.astype(str).progress_apply(lambda x: labels['label5'][x])
# Out:
#   0%|          | 0/10419 [00:00<?, ?it/s]
#   0%|          | 0/10419 [00:00<?, ?it/s]
#   0%|          | 0/10419 [00:00<?, ?it/s]
#   0%|          | 0/10419 [00:00<?, ?it/s]
#   0%|          | 0/10419 [00:00<?, ?it/s]

# %%
tracks_df = tracks_df.merge(df, on='track_id')

# %%
genres_df = tracks_df.drop_duplicates(subset=['labels_5'])[['labels_1','labels_2','labels_3','labels_4','labels_5']]

# %%
genres_df
# Out:
#        labels_1  labels_2  labels_3  labels_4  labels_5
# 0            15        84       103        82        57
# 1             9        42        59         5        48
# 2            14        82        85       128        30
# 3            14        18       134       145        89
# 4            14        82        33       102        92
# ...         ...       ...       ...       ...       ...
# 6791          1        94        62        42       142
# 6953          1       107        42        70        79
# 7370          1        66       116        12         9
# 7485          1        30       115        38        71
# 10223         2        22        78         8       107
#
# [154 rows x 5 columns]

# %%
# Cria um dicionário que mapeia o ID de cada gênero musical aos IDs de seus subgêneros
genre_dict = {
    '<ROOT>':genres_df.labels_1.unique().tolist()}

def add_node(genre_id,parent_id):
    if pd.notna(parent_id):
        if parent_id not in genre_dict:
            genre_dict[parent_id] = []
        genre_dict[parent_id].append(genre_id)



for i, row in genres_df.iterrows():
    genre_id = row['labels_3']
    parent_id = row['labels_2']
    add_node(genre_id,parent_id)
    
    genre_id = row['labels_4']
    parent_id = row['labels_3']
    add_node(genre_id,parent_id)
    
    genre_id = row['labels_5']
    parent_id = row['labels_4']
    add_node(genre_id,parent_id)
    
    
    

# In[13]:


genre_dict
# Out:
# {'<ROOT>': [15, 9, 14, 3, 0, 1, 10, 11, 13, 6, 5, 2, 7, 4, 12, 8],
#  84: [103, 100, 146, 119],
#  103: [82, 123, 41],
#  82: [57, 85, 33, 0, 7, 45, 118, 55, 33],
#  42: [59, 142, 70],
#  59: [5, 126, 145],
#  5: [48, 120, 97],
#  85: [128, 105, 135],
#  128: [30, 78],
#  18: [134, 65, 135],
#  134: [145, 147],
#  145: [89, 66],
#  33: [102, 12, 56, 98],
#  102: [92, 4, 113],
#  31: [35, 151, 90],
#  35: [81, 64, 68],
#  81: [32, 19, 48],
#  112: [36, 43, 107],
#  36: [76, 54, 29],
#  76: [137, 21, 148, 92],
#  17: [138, 84, 54],
#  138: [133, 6],
#  133: [10, 32],
#  106: [130, 49, 130, 26, 9],
#  130: [104, 130, 24],
#  104: [109, 17, 20],
#  2: [61, 28, 35],
#  61: [49, 46, 128],
#  49: [69, 48, 89],
#  14: [3, 120, 27],
#  3: [50, 60, 139],
#  50: [126, 15, 13],
#  116: [149, 145, 139, 12],
#  149: [119, 97],
#  119: [111, 63],
#  19: [6, 140, 73],
#  6: [55, 72, 93],
#  55: [11, 93, 87],
#  93: [60, 27, 25, 112],
#  60: [50, 17, 106],
#  56: [147, 14, 5],
#  147: [74, 64],
#  74: [150, 33, 119],
#  54: [99, 132, 79],
#  99: [150, 82, 76],
#  150: [29, 62],
#  48: [44, 107, 25],
#  44: [67, 38, 136],
#  21: [61, 73, 37],
#  148: [65, 45],
#  65: [136, 129, 111],
#  73: [147, 100, 39],
#  75: [104, 23, 91],
#  52: [52, 45, 36],
#  45: [103, 130, 75, 67],
#  90: [123, 13, 13, 148],
#  123: [95, 96],
#  95: [31, 0, 68],
#  100: [105, 118, 108],
#  105: [73, 59, 32],
#  78: [90, 140, 8],
#  89: [94, 114, 81, 46],
#  94: [138, 117, 28, 63, 62],
#  40: [49, 16, 52],
#  12: [143, 2, 9],
#  143: [141, 75],
#  141: [21, 18],
#  126: [93, 53],
#  23: [136, 80, 44],
#  136: [152, 1],
#  152: [59],
#  47: [109, 98, 40],
#  109: [120, 87, 129],
#  120: [51, 36],
#  38: [69, 125, 71],
#  69: [3, 72, 124],
#  41: [70, 33, 16],
#  70: [21, 1, 79],
#  15: [37, 95, 134],
#  37: [22, 146, 58],
#  22: [81, 112, 71, 77, 78],
#  28: [23, 105, 16, 56],
#  80: [83, 132, 108],
#  98: [9, 101, 106],
#  9: [41, 43, 13],
#  25: [34, 61, 109],
#  34: [111, 125, 113],
#  111: [108, 68, 83],
#  66: [52, 28, 116],
#  10: [30, 124, 22],
#  30: [1, 22, 23, 89, 40, 115],
#  1: [14, 50, 66, 127, 47, 31, 101],
#  16: [82, 76, 75],
#  0: [133, 2, 139],
#  107: [57, 15, 42],
#  57: [85, 31, 5],
#  39: [10, 99, 125],
#  124: [8, 43],
#  7: [146, 144, 150],
#  146: [66, 30],
#  64: [72, 90, 80, 91, 90, 44],
#  72: [99, 83, 143],
#  125: [103, 62],
#  27: [144, 124, 117],
#  144: [58, 122],
#  58: [141, 65, 84],
#  20: [37, 15, 58],
#  43: [47, 14, 47],
#  83: [84, 60, 7, 38],
#  68: [91, 97, 34],
#  91: [138, 6, 135],
#  4: [19, 104, 127],
#  139: [96, 12],
#  96: [70, 57, 88],
#  108: [56, 118, 7],
#  97: [142, 77, 80],
#  142: [74, 115],
#  87: [123, 54, 18],
#  11: [53, 11, 115],
#  53: [53, 63, 79],
#  24: [40, 131, 126],
#  129: [4, 149],
#  86: [141, 71, 86],
#  118: [25, 106, 116],
#  71: [94, 92, 134],
#  77: [88, 69, 112],
#  88: [131, 110, 153],
#  131: [20, 64],
#  113: [121, 35, 148],
#  121: [10, 24],
#  26: [34, 133, 41],
#  13: [131, 116, 86, 2],
#  62: [122, 39, 114, 137, 87, 42],
#  122: [114, 121],
#  114: [78, 85, 46],
#  67: [102, 20, 94],
#  92: [51, 101, 26],
#  51: [29, 88, 96],
#  29: [143, 98, 77],
#  117: [8, 144, 127],
#  8: [51, 27, 107],
#  32: [122, 149, 129],
#  101: [3, 113, 86],
#  132: [132, 100],
#  140: [110, 152],
#  110: [102, 4, 95],
#  79: [26, 151, 117, 18],
#  46: [24, 17, 67],
#  115: [74, 11, 110, 38],
#  63: [128, 142, 137],
#  151: [42],
#  137: [140, 55],
#  127: [19, 39],
#  135: [121, 0]}

# %%
from sklearn import svm
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

from sklearn_hierarchical_classification.classifier import HierarchicalClassifier
from sklearn_hierarchical_classification.constants import ROOT
from sklearn_hierarchical_classification.metrics import h_fbeta_score, multi_labeled

# %%
base_estimator = make_pipeline(
    TruncatedSVD(n_components=24),
    svm.SVC(
        gamma=0.001,
        kernel="rbf",
        probability=True
    ),
)
clf = HierarchicalClassifier(
    base_estimator=base_estimator,
    class_hierarchy=genre_dict,
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    tracks_df.feature.values.tolist(),
    tracks_df.labels_5.values.tolist(),
    test_size=0.2,
    random_state=2,
)

# %%
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("Classification Report:\n", classification_report(y_test, y_pred))
